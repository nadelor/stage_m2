# %% [markdown]
# # I. ANALYSE DES DONNEES BRUTES AVANT IMPUTATION

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# loading file
df_tabular = pd.read_csv("df_adm_pv_ioa_med_radio_labo_pel22_tabular.csv", sep=',')
# Out:
# /tmp/ipykernel_520081/973993149.py:8: DtypeWarning: Columns (76,79,82,86,90,92,94,95,96,98,99,100,101,103,104,105,108,109,110,111,112,114,115,124,126,133,136,137,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tabular = pd.read_csv("df_adm_pv_ioa_med_radio_labo_pel22_tabular.csv", sep=',')

# %% [markdown]
# # Set all date in date hour format

# %%
import pandas as pd
import numpy as np

# 1. Identify all columns with "date" in the name
date_columns = [col for col in df_tabular.columns if 'date' in col.lower()]

for col in date_columns:
    try:
        # 2. Convert to datetime objects
        df_tabular[col] = pd.to_datetime(df_tabular[col], errors='coerce')

        # 3. Apply the ISO 8601 Default Format: YYYY-MM-DD HH:MM:SS
        # This is the cleanest format for data processing and sorting
        df_tabular[col] = df_tabular[col].dt.strftime('%Y-%m-%d %H:%M:%S')

        # 4. Handle missing values
        df_tabular[col] = df_tabular[col].replace('NaT', np.nan)

    except Exception as e:
        print(f"⚠️ Could not process column '{col}': {e}")

print("✅ All date columns are now in ISO 8601 Default Format (YYYY-MM-DD HH:MM:SS).")
display(df_tabular[date_columns].head())
# Out:
# ✅ All date columns are now in ISO 8601 Default Format (YYYY-MM-DD HH:MM:SS).
#     datetime_admission          date_sortie   date_tri_ioa_begin  \
# 0  2022-01-01 00:08:00  2022-01-02 09:33:00  2022-01-01 00:19:00
# 1  2022-01-01 00:17:00  2022-01-02 14:55:00  2022-01-01 00:28:00
# 2  2022-01-01 00:22:00  2022-01-01 13:15:00  2022-01-01 00:34:00
# 3  2022-01-01 00:31:00  2022-01-01 02:05:00  2022-01-01 00:49:00
# 4  2022-01-01 00:35:00  2022-01-01 06:24:00  2022-01-01 00:42:00
#
#       date_tri_ioa_end date_hour_vitals          sample_date
# 0  2022-01-01 00:29:00              NaN  2022-01-01 01:00:00
# 1  2022-01-01 00:33:00              NaN  2022-01-01 01:05:00
# 2  2022-01-01 00:40:00              NaN  2022-01-01 01:20:00
# 3  2022-01-01 00:52:00              NaN                  NaN
# 4  2022-01-01 00:47:00              NaN  2022-01-01 03:00:00

# %% [markdown]
# # Missing data check

# %%
# ====================================================
# STEP 1: MISSING DATA ANALYSIS
# ====================================================


# Ensure all columns with NaNs are visible in the console
pd.set_option('display.max_rows', None)

# Handle empty strings and whitespace-only cells in 'diag'
# This addresses your discovery that 'diag' had ~20% hidden missing values
df_tabular = df_tabular.replace(r'^\s*$', np.nan, regex=True)
print("✅ Cleaning complete: Whitespace-only strings converted to NaN.")

# Calculate missing value statistics
missing_count = df_tabular.isnull().sum()
missing_percentage = (missing_count / len(df_tabular)) * 100

# Create summary DataFrame
df_missing = pd.DataFrame({
    'Missing Values': missing_count,
    'Percentage (%)': missing_percentage
})

# Filter for variables with at least one missing entry
df_missing_filtered = df_missing[df_missing['Missing Values'] > 0].sort_values(by='Percentage (%)', ascending=False)

print("\n📊 MISSING DATA STATISTICS (df_tabular):")
print("-" * 60)
print(df_missing_filtered)
print("-" * 60)
print(f"Total columns with missing data: {len(df_missing_filtered)} out of {df_tabular.shape[1]}")

# =========================================================
# STEP 2: VISUALIZATION OF MISSING DATA
# ==========================================================

# 1. Filter criteria: exclude technical status columns and specific timestamps
to_exclude = ['date_prlvt', 'date_heure_vitals']
df_plot_final = df_missing_filtered[
    (~df_missing_filtered.index.str.endswith('_status')) &
    (~df_missing_filtered.index.isin(to_exclude))
]

# 2. Data Preparation for Plotting
plot_data = df_plot_final.reset_index()
plot_data.columns = ['Variable', 'Count', 'Percentage']

# 3. Figure Creation
plt.figure(figsize=(12, 10), facecolor='white')
ax = plt.gca()
ax.set_facecolor('white')

# 4. Barplot Generation
sns.barplot(x='Percentage', y='Variable', data=plot_data, palette="viridis")

# 5. Styling (Black text for high contrast and readability)
plt.title('📊 MISSING DATA ANALYSIS', fontsize=18, fontweight='bold', color='black', pad=20)
plt.xlabel('Missingness Rate (%)', fontsize=13, fontweight='bold', color='black')
plt.ylabel('Clinical Variables', fontsize=13, fontweight='bold', color='black')

plt.yticks(color='black', fontweight='bold', fontsize=11)
plt.xticks(color='black', fontweight='bold')

# 6. Annotate bars with percentage values
for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{width:.1f}%',
                (width + 1, p.get_y() + p.get_height()/2),
                va='center', fontsize=11, fontweight='bold', color='black')

# Clean up layout by removing redundant spines
sns.despine(left=True, bottom=True)

plt.tight_layout()
plt.show()
# Out:
# ✅ Cleaning complete: Whitespace-only strings converted to NaN.
#
# 📊 MISSING DATA STATISTICS (df_tabular):
# ------------------------------------------------------------
#                          Missing Values  Percentage (%)
# axa_arixtra                       29875       99.996653
# nuclear_medicine_1                29874       99.993306
# lcr_aspect_1                      29873       99.989958
# ct_scan_3                         29873       99.989958
# xray_3                            29868       99.973223
# ultrasound_2                      29865       99.963181
# aiia_pradaxa                      29844       99.892891
# axa_hnf                           29842       99.886196
# axa_hbpm                          29839       99.876155
# radio_interventional_1            29836       99.866113
# mri_2                             29831       99.849377
# iron                              29786       99.698755
# lactates_v                        29779       99.675325
# axa_xarelto                       29738       99.538091
# ct_scan_2                         29734       99.524702
# xray_2                            29722       99.484536
# lcr_aspect_2                      29656       99.263623
# lcr_aspect_3                      29653       99.253581
# ferritin                          29598       99.069487
# axa_eliquis                       29523       98.818450
# pct                               29520       98.808408
# ultrasound_1                      29378       98.333110
# hemocue                           29168       97.630205
# breathalyzer                      29155       97.586692
# diag                              28949       96.897175
# ckmb                              28911       96.769983
# date_hour_vitals                  28779       96.328156
# bnp                               28640       95.862900
# calcium_ionized                   28054       93.901459
# lactates_a                        27801       93.054626
# gds_pco2                          27671       92.619494
# gds_hco3                          27671       92.619494
# gds_po2                           27670       92.616147
# gds_so2                           27670       92.616147
# urine_dipstick_clean              27669       92.612800
# gds_ph                            27665       92.599411
# gds_origin                        27663       92.592717
# fibrinogen                        27613       92.425358
# mri_1                             27169       90.939215
# ddimer                            26620       89.101620
# lipase                            26472       88.606239
# ck                                26283       87.973624
# culture                           25576       85.607176
# pupil_right                       25277       84.606373
# pupil_left                        25273       84.592984
# rr                                24770       82.909359
# troponine                         24611       82.377159
# xray_1                            23137       77.443433
# ct_scan_1                         22394       74.956487
# cap_blood_sugar_mmol_L            21927       73.393359
# bili_total                        21019       70.354130
# alp                               21015       70.340742
# alat                              20856       69.808542
# asat                              20855       69.805195
# pt                                16305       54.575579
# aptt                              16216       54.277681
# mode_sortie                       14601       48.872004
# monocytes                         14431       48.302986
# lymphocytes                       14431       48.302986
# neutrophils                       14431       48.302986
# eosinophils                       14431       48.302986
# basophils                         14431       48.302986
# crp                               14141       47.332307
# calcium                           13254       44.363369
# platelets                         13069       43.744142
# leucocytes                        13065       43.730754
# urea                              13043       43.657116
# creatinine                        13041       43.650422
# sodium                            13029       43.610256
# potassium                         13029       43.610256
# hemoglobine                       12999       43.509841
# sample_date                       12536       41.960102
# o2_flow                           12137       40.624582
# pain                              11848       39.657250
# gcs                               10538       35.272459
# temp                               8835       29.572232
# disposition                        8759       29.317847
# sat                                8456       28.303655
# hr                                 8402       28.122908
# dbp                                8370       28.015799
# mbp                                8370       28.015799
# sbp                                8368       28.009104
# decision_urgence                    281        0.940554
# duration_triage_ioa_min              48        0.160664
# date_tri_ioa_begin                    2        0.006694
# date_sortie                           1        0.003347
# ------------------------------------------------------------
# Total columns with missing data: 86 out of 174
# /tmp/ipykernel_520081/559745502.py:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Percentage', y='Variable', data=plot_data, palette="viridis")
# /tmp/ipykernel_520081/559745502.py:74: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/nadia/pycharm_project_nad/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Pour le diagnostic, à date je peux rien faire, pour le transport je fvais rajouter un lvl "inconnu", et pour le reste des signes vitaux je vais imputer les vraies données manquantes par la norme et creer une variable is_measured binaire pour différencier les vrais NaN (non mesurés) des valeurs imputées (mesurés mais normalisés). Parcontre pour les données abbérantes je les mettrai en Nan dans un second temps, et essayé d'imputer par la mediane du cluster (après avoir fait du clustering sur les données brutes) pour garder une cohérence clinique. je creerai une colonne indicative aussi pour differencier celles qui étaient aberrantes, mais pour moi cette colonne n'a rien a faire dans le clustering final, elle servira juste pour la transparence et la vérification de la qualité de l'imputation.

# %% [markdown]
# # II. IMPUTATION PAR LA NORME POUR LES SIGNES VITAUX MANQUANTS ET PAR INCONNU POUR LE TRANSPORT #

# %%
# ==============================================================================
# IMPUTATION BY CLINICAL NORM — NaN only, flags and status unchanged
# ==============================================================================

CLINICAL_NORMS = {
    # Numeric vitals
    "temp":                   37.0,
    "hr":                     75.0,
    "sbp":                    120.0,
    "dbp":                    70.0,
    "sat":                    98.0,
    "rr":                     18.0,
    "gcs":                    15.0,
    "cap_blood_sugar_mmol_L": 5.5,
    "pain":                   0.0,
    "pupil_right":            3.0,
    "pupil_left":             3.0,
    "o2_flow":                0.0,
    "hemocue":                13.0,
    "breathalyzer":           0.0,

    # Categorical
    "urine_dipstick_clean":   "negative",
    "transport_grouped":      "unknown",
}

def impute_by_norm(df: pd.DataFrame) -> pd.DataFrame:
    """
    Replace NaN values with clinical norms.
    Flags (is_*_measured) and status (*_status) are NOT touched.
    """
    df = df.copy()

    for col, norm in CLINICAL_NORMS.items():
        if col in df.columns:
            n_missing = df[col].isna().sum()
            if n_missing > 0:
                df[col] = df[col].fillna(norm)
                print(f"  {col} : {n_missing} NaN → {norm}")

    print("\n✅ Imputation by norm complete — flags and status unchanged.")
    return df


# ── Call ───────────────────────────────────────────────────────────────────────
df_imputed = impute_by_norm(df_tabular)
# Out:
#   temp : 8835 NaN → 37.0
#   hr : 8402 NaN → 75.0
#   sbp : 8368 NaN → 120.0
#   dbp : 8370 NaN → 70.0
#   sat : 8456 NaN → 98.0
#   rr : 24770 NaN → 18.0
#   gcs : 10538 NaN → 15.0
#   cap_blood_sugar_mmol_L : 21927 NaN → 5.5
#   pain : 11848 NaN → 0.0
#   pupil_right : 25277 NaN → 3.0
#   pupil_left : 25273 NaN → 3.0
#   o2_flow : 12137 NaN → 0.0
#   hemocue : 29168 NaN → 13.0
#   breathalyzer : 29155 NaN → 0.0
#   urine_dipstick_clean : 27669 NaN → negative
#
# ✅ Imputation by norm complete — flags and status unchanged.

# %%
def inspect_status_orphans(df):
    # Dictionnaire des paires (Valeur numérique : Colonne Statut)
    check_pairs = {
        'temp': 'temp_status',
        'hr': 'hr_status',
        'sat': 'sat_status',
        'rr': 'rr_status',
        'gcs': 'gcs_status',
        'cap_blood_sugar_mmol_L': 'cap_blood_sugar_status',
        'pain': 'pain_status',
        'hemocue': 'hemocue_status'
    }

    print(f"\n{'!'*20} ORPHAN VALUES REPORT {'!'*20}")
    found_any = False

    for val_col, stat_col in check_pairs.items():
        if val_col in df.columns and stat_col in df.columns:
            # On cherche : Valeur présente MAIS Statut est NaN
            orphans = df[df[stat_col].isna() & df[val_col].notna()]

            if not orphans.empty:
                found_any = True
                print(f"\n⚠️ Column [{val_col}] has {len(orphans)} values not captured by [{stat_col}]:")
                # On affiche les valeurs uniques qui posent problème pour comprendre pourquoi
                problem_values = sorted(orphans[val_col].unique())
                print(f"   --> Problematic values: {problem_values}")

                # Optionnel : voir les premières lignes concernées
                # display(orphans[[val_col, stat_col]].head(5))

    if not found_any:
        print("\n✅ Perfect! All numeric values have a corresponding clinical status.")

# Appel de l'inspection
inspect_status_orphans(df_imputed)
# Out:
# !!!!!!!!!!!!!!!!!!!! ORPHAN VALUES REPORT !!!!!!!!!!!!!!!!!!!!
#
# ✅ Perfect! All numeric values have a corresponding clinical status.

# %%
# =========================================================
# FINAL OUTCOME CLEANING & MISSING DURATION AUDIT
# =========================================================

# --- 1. CLEANING DIAGNOSIS & DISPOSITION ---
# These represent our clinical labels for the triage project.
outcome_cols = ['diag', 'disposition']

print("🧹 Cleaning outcomes and imputing 'unknown' for missing labels...")

for col in outcome_cols:
    if col in df_imputed.columns:
        # Standardize text (lowercase & strip whitespace)
        df_imputed[col] = df_imputed[col].astype(str).str.lower().str.strip()

        # Replace text-based nulls with 'unknown'
        df_imputed[col] = df_imputed[col].replace(['nan', 'none', '', 'nat', 'null'], 'unknown')

        # Final safety fill for true NaNs
        df_imputed[col] = df_imputed[col].fillna('unknown')

print(f"✅ NaNs remaining in 'diag'        : {df_imputed['diag'].isna().sum()}")
print(f"✅ NaNs remaining in 'disposition' : {df_imputed['disposition'].isna().sum()}")

# --- 2. INVESTIGATING MISSING TRIAGE DURATIONS ---
# Duration is a key feature for clustering (GMM). We need to know why 49 records are missing it.
mask_missing_duration = df_imputed['duration_triage_ioa_min'].isna()
df_check_time = df_imputed.loc[mask_missing_duration,
                               ['date_tri_ioa_begin', 'date_tri_ioa_end', 'duration_triage_ioa_min']].copy()

print(f"\n🔍 INVESTIGATING {len(df_check_time)} RECORDS WITH MISSING DURATION:")
print("-" * 60)

if not df_check_time.empty:
    # Display the first 10 problematic timestamps
    display(df_check_time.head(10))

    # Quick Diagnostic: Are the timestamps themselves missing?
    missing_begin = df_check_time['date_tri_ioa_begin'].isna().sum()
    missing_end = df_check_time['date_tri_ioa_end'].isna().sum()

    print(f"\n📊 Diagnostic Summary:")
    print(f"- Missing 'begin' timestamp : {missing_begin}")
    print(f"- Missing 'end' timestamp   : {missing_end}")
    print(f"💡 Note: If timestamps exist but duration is NaN, check for negative intervals or format errors.")
else:
    print("✅ No missing durations found.")

# --- 3. FINAL IMPUTATION FOR DURATION (Cluster Median) ---
# As per your pipeline [2026-01-23]: Impute aberrant data with Cluster Median
# For now, we use global median until clusters are defined.
if df_imputed['duration_triage_ioa_min'].isna().any():
    median_val = df_imputed['duration_triage_ioa_min'].median()
    df_imputed['duration_triage_ioa_min'] = df_imputed['duration_triage_ioa_min'].fillna(median_val)
    print(f"\n📥 Final Imputation: {len(df_check_time)} durations filled with median ({median_val} min).")
# Out:
# 🧹 Cleaning outcomes and imputing 'unknown' for missing labels...
# ✅ NaNs remaining in 'diag'        : 0
# ✅ NaNs remaining in 'disposition' : 0
#
# 🔍 INVESTIGATING 48 RECORDS WITH MISSING DURATION:
# ------------------------------------------------------------
#        date_tri_ioa_begin     date_tri_ioa_end  duration_triage_ioa_min
# 184   2022-01-03 13:39:00  2022-01-03 08:13:00                      NaN
# 947   2022-01-12 15:43:00  2022-01-11 20:25:00                      NaN
# 2482  2022-01-29 02:17:00  2022-01-28 12:56:00                      NaN
# 3028  2022-02-03 15:11:00  2022-02-03 12:54:00                      NaN
# 4044  2022-02-16 14:00:00  2022-02-14 12:34:00                      NaN
# 4095  2022-02-15 00:07:00  2022-02-14 22:23:00                      NaN
# 4426  2022-02-18 20:33:00  2022-02-18 14:58:00                      NaN
# 4554  2022-02-20 06:43:00  2022-02-20 04:34:00                      NaN
# 4583  2022-02-20 21:29:00  2022-02-20 16:44:00                      NaN
# 5482  2022-03-03 18:50:00  2022-03-03 07:24:00                      NaN
# 📊 Diagnostic Summary:
# - Missing 'begin' timestamp : 2
# - Missing 'end' timestamp   : 0
# 💡 Note: If timestamps exist but duration is NaN, check for negative intervals or format errors.
#
# 📥 Final Imputation: 48 durations filled with median (5.0 min).

# %% [markdown]
# # III. DATA DESCRIPTION AND VISUALIZATION #

# %%
# =========================================================
# STEP 3: POST-IMPUTATION DESCRIPTIVE TABLE (CORRECTED)
# =========================================================

def get_descriptive_table(df, title):
    """
    Generates a comprehensive summary of clinical data post-imputation.
    Excludes identifiers, dates, and lab results.
    """
    print(f"\n{'='*30} {title.upper()} {'='*30}")

    # 1. Define lists to exclude
    lab_results = [
        'alat', 'asat', 'axa_hnf', 'axa_arixtra', 'axa_eliquis', 'axa_hbpm',
        'axa_xarelto', 'aiia_pradaxa', 'bnp', 'gds_hco3', 'bili_total', 'ck',
        'ckmb', 'crp', 'calcium_ionized', 'calcium', 'creatinine', 'ddimer',
        'iron', 'ferritin', 'fibrinogen', 'hemoglobine', 'lactates_a',
        'lactates_v', 'leucocytes', 'lipase', 'lymphocytes', 'monocytes',
        'alp', 'basophils', 'eosinophils', 'neutrophils', 'platelets',
        'potassium', 'pct', 'gds_so2', 'sodium', 'aptt', 'pt', 'troponine',
        'urea', 'culture', 'gds_origin', 'lcr_aspect_1', 'lcr_aspect_2',
        'lcr_aspect_3', 'gds_pco2', 'gds_ph', 'gds_po2'
    ]

    cols_imaging = [
    'ultrasound_1', 'ultrasound_2', 'ct_scan_1', 'ct_scan_2', 'ct_scan_3',
    'xray_1', 'xray_2', 'xray_3', 'mri_1', 'mri_2',
    'radio_interventional_1', 'nuclear_medicine_1'
]

    base_exclude = [
        'nda', 'datetime_admission', 'sample_date', 'chief_complaint', 'date_admission',
        'date_hour_vitals', 'date_tri_ioa_begin', 'date_tri_ioa_end', 'diag', 'date_sortie'
    ]

    # CORRECT WAY: Merge the lists into one flat list
    total_exclude = base_exclude + lab_results + cols_imaging

    # 2. Smart column classification
    numeric_cols = []
    categorical_cols = []

    for col in df.columns:
        if col in total_exclude:
            continue

        # Logic: If it has these prefixes/suffixes, it's CATEGORICAL (even if numeric 0/1)
        is_status_var = any(col.startswith(pre) for pre in ['has_', 'is_', 'had_']) or col.endswith('_status')

        if is_status_var:
            categorical_cols.append(col)
        elif pd.api.types.is_numeric_dtype(df[col]):
            numeric_cols.append(col)
        else:
            categorical_cols.append(col)

    # 3. NUMERIC SUMMARY (Vitals, Age, etc.)
    if numeric_cols:
        print("\n📊 --- NUMERIC VARIABLES (Vitals & Demographics) ---")
        num_summary = df[numeric_cols].agg(['count', 'mean', 'std', 'min', 'max']).T
        num_summary['missing_%'] = (df[numeric_cols].isna().sum() / len(df) * 100).round(2)
        display(num_summary.round(2))

    # 4. CATEGORICAL & STATUS SUMMARY
    if categorical_cols:
        print("\n📋 --- CATEGORICAL & STATUS DISTRIBUTIONS ---")
        summaries = []
        for col in categorical_cols:
            counts = df[col].value_counts(dropna=False)
            percents = (df[col].value_counts(dropna=False, normalize=True) * 100).round(1)

            temp_df = pd.DataFrame({
                'Variable': col,
                'Level': counts.index,
                'N': counts.values,
                'Percentage (%)': percents.values
            })
            summaries.append(temp_df)

        final_cat_summary = pd.concat(summaries, ignore_index=True)
        display(final_cat_summary)

# --- FINAL EXECUTION ---
get_descriptive_table(df_imputed, "Post-Imputation Clinical Profile")


####### virer les radio detailedet date sortie la setter en date
# Out:
# ============================== POST-IMPUTATION CLINICAL PROFILE ==============================
#
# 📊 --- NUMERIC VARIABLES (Vitals & Demographics) ---
#                               count     mean    std      min     max  \
# age                         29876.0    46.64  22.84     0.00   104.0
# uam_service                 29876.0  9780.00   0.00  9780.00  9780.0
# duration_triage_ioa_min     29876.0     6.11   3.56     2.00    30.0
# triage                      29876.0     3.18   0.89     1.00     5.0
# sbp                         29876.0   127.14  19.70    46.00   253.0
# dbp                         29876.0    74.54  12.74    20.00   159.0
# mbp                         21506.0    94.18  15.62    30.70   190.3
# hr                          29876.0    79.17  14.47    20.00   220.0
# temp                        29876.0    36.88   0.49    32.20    40.5
# sat                         29876.0    97.87   1.74    49.00   100.0
# rr                          29876.0    18.07   2.47     4.00    60.0
# o2_flow                     29876.0     0.14   1.04     0.00    15.0
# gcs                         29876.0    14.90   0.65     3.00    15.0
# cap_blood_sugar_mmol_L      29876.0     5.85   1.62     1.66    33.3
# pupil_right                 29876.0     2.93   0.32     1.00     6.0
# pupil_left                  29876.0     2.93   0.32     1.00     6.0
# pain                        29876.0     1.43   2.58     0.00    10.0
# breathalyzer                29876.0     0.06   4.53     0.00   600.0
# hemocue                     29876.0    12.97   0.46     5.20    18.4
# count_ultrasound            29876.0     0.02   0.13     0.00     2.0
# count_ct_scan               29876.0     0.26   0.45     0.00     3.0
# count_xray                  29876.0     0.23   0.43     0.00     3.0
# count_mri                   29876.0     0.09   0.29     0.00     2.0
# count_radio_interventional  29876.0     0.00   0.04     0.00     1.0
# count_nuclear_medicine      29876.0     0.00   0.01     0.00     1.0
# imaging_exam_count          29876.0     0.60   0.65     0.00     4.0
# bio_exam_count              29876.0     0.80   0.82     0.00     4.0
#
#                             missing_%
# age                              0.00
# uam_service                      0.00
# duration_triage_ioa_min          0.00
# triage                           0.00
# sbp                              0.00
# dbp                              0.00
# mbp                             28.02
# hr                               0.00
# temp                             0.00
# sat                              0.00
# rr                               0.00
# o2_flow                          0.00
# gcs                              0.00
# cap_blood_sugar_mmol_L           0.00
# pupil_right                      0.00
# pupil_left                       0.00
# pain                             0.00
# breathalyzer                     0.00
# hemocue                          0.00
# count_ultrasound                 0.00
# count_ct_scan                    0.00
# count_xray                       0.00
# count_mri                        0.00
# count_radio_interventional       0.00
# count_nuclear_medicine           0.00
# imaging_exam_count               0.00
# bio_exam_count                   0.00
# 📋 --- CATEGORICAL & STATUS DISTRIBUTIONS ---
#                                Variable                                 Level  \
# 0                                   sex                                     M
# 1                                   sex                                     F
# 2                                   sex                                     I
# 3                              hospital                                   PEL
# 4                           mode_sortie                                   NaN
# 5                           mode_sortie                          A - Domicile
# 6                           mode_sortie                    B1 - Transfert MCO
# 7                           mode_sortie                    B2 - Transfert SSR
# 8                           mode_sortie                    B4 - Transfert PSY
# 9                           mode_sortie                           C0 - Décédé
# 10                          mode_sortie                     D2 - Mutation SSR
# 11                          mode_sortie  C1 - Transfert provisoire (<48h) MCO
# 12                          mode_sortie                            A2 - Fugue
# 13                          mode_sortie            B3 - Transfert Long Séjour
# 14                     decision_urgence                       Hospitalisation
# 15                     decision_urgence                          Consultation
# 16                     decision_urgence                                   NaN
# 17                     decision_urgence                       Pas de décision
# 18                    transport_grouped                              Personal
# 19                    transport_grouped                    Emergency services
# 20                    transport_grouped                               Unknown
# 21                    transport_grouped                             Ambulance
# 22                    transport_grouped                   Post medical advice
# 23                           triage_raw                  Urgent (médecin <1h)
# 24                           triage_raw              Peu urgent (médecin <2h)
# 25                           triage_raw          Très urgent (médecin <20min)
# 26                           triage_raw              Non urgent (médecin <3h)
# 27                           triage_raw           Réanimation (médecin <1min)
# 28                            bp_status                          normotension
# 29                            bp_status                          not_measured
# 30                            bp_status                          hypertension
# 31                            bp_status                           hypotension
# 32                       is_bp_measured                                     1
# 33                       is_bp_measured                                     0
# 34                            hr_status                           normocardia
# 35                            hr_status                          not_measured
# 36                            hr_status                           tachycardia
# 37                            hr_status                           bradycardia
# 38                       is_hr_measured                                     1
# 39                       is_hr_measured                                     0
# 40                          temp_status                          normothermia
# 41                          temp_status                          not_measured
# 42                          temp_status                          hyperthermia
# 43                          temp_status                           hypothermia
# 44                     is_temp_measured                                     1
# 45                     is_temp_measured                                     0
# 46                           sat_status                                normal
# 47                           sat_status                          not_measured
# 48                           sat_status                               hypoxia
# 49                           sat_status                        severe hypoxia
# 50                      is_sat_measured                                     1
# 51                      is_sat_measured                                     0
# 52                            rr_status                          not_measured
# 53                            rr_status                                normal
# 54                            rr_status                             tachypnea
# 55                            rr_status                             bradypnea
# 56                       is_rr_measured                                     0
# 57                       is_rr_measured                                     1
# 58                       o2_flow_status                                   off
# 59                       o2_flow_status                          not_measured
# 60                       o2_flow_status                                    on
# 61                       is_o2_measured                                     1
# 62                       is_o2_measured                                     0
# 63                           gcs_status                                normal
# 64                           gcs_status                          not_measured
# 65                           gcs_status                   moderate_impairment
# 66                           gcs_status                     severe_impairment
# 67                      is_gcs_measured                                     1
# 68                      is_gcs_measured                                     0
# 69               cap_blood_sugar_status                          not_measured
# 70               cap_blood_sugar_status                         normoglycemia
# 71               cap_blood_sugar_status                         hyperglycemia
# 72               cap_blood_sugar_status                          hypoglycemia
# 73   is_cap_blood_sugar_mmol_L_measured                                     0
# 74   is_cap_blood_sugar_mmol_L_measured                                     1
# 75                        pupils_status                          not_measured
# 76                        pupils_status                                normal
# 77                        pupils_status                                myosis
# 78                        pupils_status                             mydriasis
# 79                    anisocoria_status                          not_measured
# 80                    anisocoria_status                                    no
# 81                    anisocoria_status                                   yes
# 82                   is_pupils_measured                                     0
# 83                   is_pupils_measured                                     1
# 84                 urine_dipstick_clean                              negative
# 85                 urine_dipstick_clean                        blood_positive
# 86                 urine_dipstick_clean                          ecbu_ordered
# 87                 urine_dipstick_clean                   leukocytes_positive
# 88                 urine_dipstick_clean                              beta hcg
# 89                 urine_dipstick_clean                     nitrites_positive
# 90                 urine_dipstick_clean                      ketones_positive
# 91                 urine_dipstick_clean                      protein_positive
# 92     is_urine_dipstick_clean_measured                                     0
# 93     is_urine_dipstick_clean_measured                                     1
# 94          urine_dipstick_clean_status                          not_measured
# 95          urine_dipstick_clean_status                              positive
# 96          urine_dipstick_clean_status                              negative
# 97                          pain_status                          not_measured
# 98                          pain_status                               no_pain
# 99                          pain_status                         moderate_pain
# 100                         pain_status                             mild_pain
# 101                         pain_status                           severe_pain
# 102                    is_pain_measured                                     1
# 103                    is_pain_measured                                     0
# 104                 breathalyzer_status                          not_measured
# 105                 breathalyzer_status                              positive
# 106                 breathalyzer_status                              negative
# 107            is_breathalyzer_measured                                     0
# 108            is_breathalyzer_measured                                     1
# 109                 is_hemocue_measured                                     0
# 110                 is_hemocue_measured                                     1
# 111                      hemocue_status                          not_measured
# 112                      hemocue_status                       moderate_anemia
# 113                      hemocue_status                                normal
# 114                      hemocue_status                         severe_anemia
# 115                             had_ekg                                     0
# 116                             had_ekg                                     1
# 117                         disposition                       retour domicile
# 118                         disposition                               unknown
# 119                         disposition                hospitalisation au chu
# 120                         disposition      uhcd puis hospitalisation au chu
# 121                         disposition                         uhcd puis rad
# 122                         disposition                    transfert hors chu
# 123                         disposition          uhcd puis transfert hors chu
# 124                      has_ultrasound                                     0
# 125                      has_ultrasound                                     1
# 126                         has_ct_scan                                     0
# 127                         has_ct_scan                                     1
# 128                            has_xray                                     0
# 129                            has_xray                                     1
# 130                             has_mri                                     0
# 131                             has_mri                                     1
# 132            has_radio_interventional                                     0
# 133            has_radio_interventional                                     1
# 134                has_nuclear_medicine                                     0
# 135                has_nuclear_medicine                                     1
# 136                     has_imaging_any                                     1
# 137                     has_imaging_any                                     0
# 138                       has_blood_gas                                     0
# 139                       has_blood_gas                                     1
# 140                         is_aXa_aIIa                                     0
# 141                         is_aXa_aIIa                                     1
# 142                 has_lumbar_puncture                                     0
# 143                 has_lumbar_puncture                                     1
# 144                         is_lactates                                     0
# 145                         is_lactates                                     1
# 146                         has_culture                                     0
# 147                         has_culture                                     1
# 148                       is_leucocytes                                     1
# 149                       is_leucocytes                                     0
# 150                    is_formule_leuco                                     1
# 151                    is_formule_leuco                                     0
# 152                             is_alat                                     0
# 153                             is_alat                                     1
# 154                             is_asat                                     0
# 155                             is_asat                                     1
# 156                              is_bnp                                     0
# 157                              is_bnp                                     1
# 158                       is_bili_total                                     0
# 159                       is_bili_total                                     1
# 160                               is_ck                                     0
# 161                               is_ck                                     1
# 162                             is_ckmb                                     0
# 163                             is_ckmb                                     1
# 164                              is_crp                                     1
# 165                              is_crp                                     0
# 166                  is_calcium_ionized                                     0
# 167                  is_calcium_ionized                                     1
# 168                          is_calcium                                     1
# 169                          is_calcium                                     0
# 170                       is_creatinine                                     1
# 171                       is_creatinine                                     0
# 172                           is_ddimer                                     0
# 173                           is_ddimer                                     1
# 174                             is_iron                                     0
# 175                             is_iron                                     1
# 176                         is_ferritin                                     0
# 177                         is_ferritin                                     1
# 178                       is_fibrinogen                                     0
# 179                       is_fibrinogen                                     1
# 180                      is_hemoglobine                                     1
# 181                      is_hemoglobine                                     0
# 182                           is_lipase                                     0
# 183                           is_lipase                                     1
# 184                              is_alp                                     0
# 185                              is_alp                                     1
# 186                        is_platelets                                     1
# 187                        is_platelets                                     0
# 188                        is_potassium                                     1
# 189                        is_potassium                                     0
# 190                              is_pct                                     0
# 191                              is_pct                                     1
# 192                           is_sodium                                     1
# 193                           is_sodium                                     0
# 194                             is_aptt                                     0
# 195                             is_aptt                                     1
# 196                               is_pt                                     0
# 197                               is_pt                                     1
# 198                        is_troponine                                     0
# 199                        is_troponine                                     1
# 200                             is_urea                                     1
# 201                             is_urea                                     0
# 202                      has_blood_test                                     1
# 203                      has_blood_test                                     0
# 204                             is_labo                                     1
# 205                             is_labo                                     0
#
#          N  Percentage (%)
# 0    15603            52.2
# 1    14272            47.8
# 2        1             0.0
# 3    29876           100.0
# 4    14601            48.9
# 5    12532            41.9
# 6     1403             4.7
# 7      487             1.6
# 8      425             1.4
# 9      306             1.0
# 10      39             0.1
# 11      38             0.1
# 12      31             0.1
# 13      14             0.0
# 14   15102            50.5
# 15   14492            48.5
# 16     281             0.9
# 17       1             0.0
# 18   15089            50.5
# 19    6676            22.3
# 20    4868            16.3
# 21    3099            10.4
# 22     144             0.5
# 23   11288            37.8
# 24    9062            30.3
# 25    7472            25.0
# 26    1959             6.6
# 27      95             0.3
# 28   11690            39.1
# 29    8368            28.0
# 30    7295            24.4
# 31    2523             8.4
# 32   21508            72.0
# 33    8368            28.0
# 34   18682            62.5
# 35    8402            28.1
# 36    2588             8.7
# 37     204             0.7
# 38   21474            71.9
# 39    8402            28.1
# 40   19778            66.2
# 41    8835            29.6
# 42     725             2.4
# 43     538             1.8
# 44   21041            70.4
# 45    8835            29.6
# 46   20860            69.8
# 47    8456            28.3
# 48     518             1.7
# 49      42             0.1
# 50   21420            71.7
# 51    8456            28.3
# 52   24770            82.9
# 53    3487            11.7
# 54    1360             4.6
# 55     259             0.9
# 56   24770            82.9
# 57    5106            17.1
# 58   16724            56.0
# 59   12137            40.6
# 60    1015             3.4
# 61   17739            59.4
# 62   12137            40.6
# 63   19092            63.9
# 64   10538            35.3
# 65     167             0.6
# 66      79             0.3
# 67   19338            64.7
# 68   10538            35.3
# 69   21927            73.4
# 70    6284            21.0
# 71    1570             5.3
# 72      95             0.3
# 73   21927            73.4
# 74    7949            26.6
# 75   25253            84.5
# 76    4508            15.1
# 77      65             0.2
# 78      50             0.2
# 79   25253            84.5
# 80    4076            13.6
# 81     547             1.8
# 82   25253            84.5
# 83    4623            15.5
# 84   28183            94.3
# 85     592             2.0
# 86     329             1.1
# 87     313             1.0
# 88     156             0.5
# 89     120             0.4
# 90     111             0.4
# 91      72             0.2
# 92   27669            92.6
# 93    2207             7.4
# 94   27669            92.6
# 95    1693             5.7
# 96     514             1.7
# 97   11848            39.7
# 98    9474            31.7
# 99    3486            11.7
# 100   2673             8.9
# 101   2395             8.0
# 102  18028            60.3
# 103  11848            39.7
# 104  29155            97.6
# 105    537             1.8
# 106    184             0.6
# 107  29155            97.6
# 108    721             2.4
# 109  29168            97.6
# 110    708             2.4
# 111  29168            97.6
# 112    394             1.3
# 113    272             0.9
# 114     42             0.1
# 115  22060            73.8
# 116   7816            26.2
# 117  16641            55.7
# 118   8759            29.3
# 119   2323             7.8
# 120    825             2.8
# 121    711             2.4
# 122    460             1.5
# 123    157             0.5
# 124  29378            98.3
# 125    498             1.7
# 126  22394            75.0
# 127   7482            25.0
# 128  23137            77.4
# 129   6739            22.6
# 130  27169            90.9
# 131   2707             9.1
# 132  29836            99.9
# 133     40             0.1
# 134  29874           100.0
# 135      2             0.0
# 136  15306            51.2
# 137  14570            48.8
# 138  27663            92.6
# 139   2213             7.4
# 140  29293            98.0
# 141    583             2.0
# 142  29649            99.2
# 143    227             0.8
# 144  27730            92.8
# 145   2146             7.2
# 146  25576            85.6
# 147   4300            14.4
# 148  16811            56.3
# 149  13065            43.7
# 150  15445            51.7
# 151  14431            48.3
# 152  20856            69.8
# 153   9020            30.2
# 154  20855            69.8
# 155   9021            30.2
# 156  28640            95.9
# 157   1236             4.1
# 158  21019            70.4
# 159   8857            29.6
# 160  26283            88.0
# 161   3593            12.0
# 162  28911            96.8
# 163    965             3.2
# 164  15735            52.7
# 165  14141            47.3
# 166  28054            93.9
# 167   1822             6.1
# 168  16622            55.6
# 169  13254            44.4
# 170  16835            56.3
# 171  13041            43.7
# 172  26620            89.1
# 173   3256            10.9
# 174  29786            99.7
# 175     90             0.3
# 176  29598            99.1
# 177    278             0.9
# 178  27613            92.4
# 179   2263             7.6
# 180  16877            56.5
# 181  12999            43.5
# 182  26472            88.6
# 183   3404            11.4
# 184  21015            70.3
# 185   8861            29.7
# 186  16807            56.3
# 187  13069            43.7
# 188  16847            56.4
# 189  13029            43.6
# 190  29520            98.8
# 191    356             1.2
# 192  16847            56.4
# 193  13029            43.6
# 194  16216            54.3
# 195  13660            45.7
# 196  16305            54.6
# 197  13571            45.4
# 198  24611            82.4
# 199   5265            17.6
# 200  16833            56.3
# 201  13043            43.7
# 202  17045            57.1
# 203  12831            42.9
# 204  17340            58.0
# 205  12536            42.0

# %%
# =========================================================
# STEP 3: POST-IMPUTATION DESCRIPTIVE TABLE
# =========================================================

def get_descriptive_table(df, title):
    """
    Generates a comprehensive summary of clinical data post-imputation.
    Optimized to prevent 'IOPub data rate exceeded' errors.
    """
    print(f"\n{'='*30} {title.upper()} {'='*30}")

    # 1. Define columns to exclude from the summary
    lab_results = [
        'alat', 'asat', 'axa_hnf', 'axa_arixtra', 'axa_eliquis', 'axa_hbpm',
        'axa_xarelto', 'aiia_pradaxa', 'bnp', 'gds_hco3', 'bili_total', 'ck',
        'ckmb', 'crp', 'calcium_ionized', 'calcium', 'creatinine', 'ddimer',
        'iron', 'ferritin', 'fibrinogen', 'hemoglobine', 'lactates_a',
        'lactates_v', 'leucocytes', 'lipase', 'lymphocytes', 'monocytes',
        'alp', 'basophils', 'eosinophils', 'neutrophils', 'platelets',
        'potassium', 'pct', 'gds_so2', 'sodium', 'aptt', 'pt', 'troponine',
        'urea', 'culture', 'gds_origin', 'lcr_aspect_1', 'lcr_aspect_2',
        'lcr_aspect_3', 'gds_pco2', 'gds_ph', 'gds_po2'
    ]

    cols_imaging = [
    'ultrasound_1', 'ultrasound_2', 'ct_scan_1', 'ct_scan_2', 'ct_scan_3',
    'xray_1', 'xray_2', 'xray_3', 'mri_1', 'mri_2',
    'radio_interventional_1', 'nuclear_medicine_1'
]

    base_exclude = [
        'nda', 'datetime_admission', 'sample_date', 'chief_complaint', 'date_admission',
        'date_hour_vitals', 'date_tri_ioa_begin', 'date_tri_ioa_end', 'diag', 'date_sortie'
    ]

    # CORRECT WAY: Merge the lists into one flat list
    total_exclude = base_exclude + lab_results + cols_imaging
    target_cols = [c for c in df.columns if c not in total_exclude]

    # 2. NUMERIC SUMMARY (Vitals, Hemocue, Blood Sugar, etc.)
    num_df = df[target_cols].select_dtypes(include=[np.number])
    if not num_df.empty:
        print("\n📊 --- NUMERIC VARIABLES ---")
        num_summary = num_df.agg(['count', 'mean', 'std', 'min', 'max']).T
        num_summary['missing_%'] = (num_df.isna().sum() / len(df) * 100).round(2)
        display(num_summary.round(2))

    # 3. CATEGORICAL & STATUS SUMMARY (Optimized approach)
    cat_df = df[target_cols].select_dtypes(exclude=[np.number])
    if not cat_df.empty:
        print("\n📋 --- CATEGORICAL & STATUS DISTRIBUTIONS ---")

        # We process column by column to keep memory usage low
        summaries = []
        for col in cat_df.columns:
            # Count occurrences including NaNs
            counts = df[col].value_counts(dropna=False)
            percents = (df[col].value_counts(dropna=False, normalize=True) * 100).round(1)

            # Create a small temp dataframe for this variable
            temp_df = pd.DataFrame({
                'Variable': col,
                'Level': counts.index,
                'N': counts.values,
                'Percentage (%)': percents.values
            })
            summaries.append(temp_df)

        # Concatenate all small summaries into one
        final_cat_summary = pd.concat(summaries, ignore_index=True)

        # Use display() instead of print(to_string) to let Jupyter handle the data flow
        display(final_cat_summary)

# --- FINAL EXECUTION ---
get_descriptive_table(df_imputed, "Post-Imputation Clinical Profile")
# Out:
# ============================== POST-IMPUTATION CLINICAL PROFILE ==============================
#
# 📊 --- NUMERIC VARIABLES ---
#                                       count     mean    std      min     max  \
# age                                 29876.0    46.64  22.84     0.00   104.0
# uam_service                         29876.0  9780.00   0.00  9780.00  9780.0
# duration_triage_ioa_min             29876.0     6.11   3.56     2.00    30.0
# triage                              29876.0     3.18   0.89     1.00     5.0
# sbp                                 29876.0   127.14  19.70    46.00   253.0
# dbp                                 29876.0    74.54  12.74    20.00   159.0
# mbp                                 21506.0    94.18  15.62    30.70   190.3
# is_bp_measured                      29876.0     0.72   0.45     0.00     1.0
# hr                                  29876.0    79.17  14.47    20.00   220.0
# is_hr_measured                      29876.0     0.72   0.45     0.00     1.0
# temp                                29876.0    36.88   0.49    32.20    40.5
# is_temp_measured                    29876.0     0.70   0.46     0.00     1.0
# sat                                 29876.0    97.87   1.74    49.00   100.0
# is_sat_measured                     29876.0     0.72   0.45     0.00     1.0
# rr                                  29876.0    18.07   2.47     4.00    60.0
# is_rr_measured                      29876.0     0.17   0.38     0.00     1.0
# o2_flow                             29876.0     0.14   1.04     0.00    15.0
# is_o2_measured                      29876.0     0.59   0.49     0.00     1.0
# gcs                                 29876.0    14.90   0.65     3.00    15.0
# is_gcs_measured                     29876.0     0.65   0.48     0.00     1.0
# cap_blood_sugar_mmol_L              29876.0     5.85   1.62     1.66    33.3
# is_cap_blood_sugar_mmol_L_measured  29876.0     0.27   0.44     0.00     1.0
# pupil_right                         29876.0     2.93   0.32     1.00     6.0
# pupil_left                          29876.0     2.93   0.32     1.00     6.0
# is_pupils_measured                  29876.0     0.15   0.36     0.00     1.0
# is_urine_dipstick_clean_measured    29876.0     0.07   0.26     0.00     1.0
# pain                                29876.0     1.43   2.58     0.00    10.0
# is_pain_measured                    29876.0     0.60   0.49     0.00     1.0
# breathalyzer                        29876.0     0.06   4.53     0.00   600.0
# is_breathalyzer_measured            29876.0     0.02   0.15     0.00     1.0
# hemocue                             29876.0    12.97   0.46     5.20    18.4
# is_hemocue_measured                 29876.0     0.02   0.15     0.00     1.0
# had_ekg                             29876.0     0.26   0.44     0.00     1.0
# has_ultrasound                      29876.0     0.02   0.13     0.00     1.0
# has_ct_scan                         29876.0     0.25   0.43     0.00     1.0
# has_xray                            29876.0     0.23   0.42     0.00     1.0
# has_mri                             29876.0     0.09   0.29     0.00     1.0
# has_radio_interventional            29876.0     0.00   0.04     0.00     1.0
# has_nuclear_medicine                29876.0     0.00   0.01     0.00     1.0
# count_ultrasound                    29876.0     0.02   0.13     0.00     2.0
# count_ct_scan                       29876.0     0.26   0.45     0.00     3.0
# count_xray                          29876.0     0.23   0.43     0.00     3.0
# count_mri                           29876.0     0.09   0.29     0.00     2.0
# count_radio_interventional          29876.0     0.00   0.04     0.00     1.0
# count_nuclear_medicine              29876.0     0.00   0.01     0.00     1.0
# imaging_exam_count                  29876.0     0.60   0.65     0.00     4.0
# has_imaging_any                     29876.0     0.51   0.50     0.00     1.0
# has_blood_gas                       29876.0     0.07   0.26     0.00     1.0
# is_aXa_aIIa                         29876.0     0.02   0.14     0.00     1.0
# has_lumbar_puncture                 29876.0     0.01   0.09     0.00     1.0
# is_lactates                         29876.0     0.07   0.26     0.00     1.0
# has_culture                         29876.0     0.14   0.35     0.00     1.0
# is_leucocytes                       29876.0     0.56   0.50     0.00     1.0
# is_formule_leuco                    29876.0     0.52   0.50     0.00     1.0
# is_alat                             29876.0     0.30   0.46     0.00     1.0
# is_asat                             29876.0     0.30   0.46     0.00     1.0
# is_bnp                              29876.0     0.04   0.20     0.00     1.0
# is_bili_total                       29876.0     0.30   0.46     0.00     1.0
# is_ck                               29876.0     0.12   0.33     0.00     1.0
# is_ckmb                             29876.0     0.03   0.18     0.00     1.0
# is_crp                              29876.0     0.53   0.50     0.00     1.0
# is_calcium_ionized                  29876.0     0.06   0.24     0.00     1.0
# is_calcium                          29876.0     0.56   0.50     0.00     1.0
# is_creatinine                       29876.0     0.56   0.50     0.00     1.0
# is_ddimer                           29876.0     0.11   0.31     0.00     1.0
# is_iron                             29876.0     0.00   0.05     0.00     1.0
# is_ferritin                         29876.0     0.01   0.10     0.00     1.0
# is_fibrinogen                       29876.0     0.08   0.26     0.00     1.0
# is_hemoglobine                      29876.0     0.56   0.50     0.00     1.0
# is_lipase                           29876.0     0.11   0.32     0.00     1.0
# is_alp                              29876.0     0.30   0.46     0.00     1.0
# is_platelets                        29876.0     0.56   0.50     0.00     1.0
# is_potassium                        29876.0     0.56   0.50     0.00     1.0
# is_pct                              29876.0     0.01   0.11     0.00     1.0
# is_sodium                           29876.0     0.56   0.50     0.00     1.0
# is_aptt                             29876.0     0.46   0.50     0.00     1.0
# is_pt                               29876.0     0.45   0.50     0.00     1.0
# is_troponine                        29876.0     0.18   0.38     0.00     1.0
# is_urea                             29876.0     0.56   0.50     0.00     1.0
# has_blood_test                      29876.0     0.57   0.50     0.00     1.0
# bio_exam_count                      29876.0     0.80   0.82     0.00     4.0
# is_labo                             29876.0     0.58   0.49     0.00     1.0
#
#                                     missing_%
# age                                      0.00
# uam_service                              0.00
# duration_triage_ioa_min                  0.00
# triage                                   0.00
# sbp                                      0.00
# dbp                                      0.00
# mbp                                     28.02
# is_bp_measured                           0.00
# hr                                       0.00
# is_hr_measured                           0.00
# temp                                     0.00
# is_temp_measured                         0.00
# sat                                      0.00
# is_sat_measured                          0.00
# rr                                       0.00
# is_rr_measured                           0.00
# o2_flow                                  0.00
# is_o2_measured                           0.00
# gcs                                      0.00
# is_gcs_measured                          0.00
# cap_blood_sugar_mmol_L                   0.00
# is_cap_blood_sugar_mmol_L_measured       0.00
# pupil_right                              0.00
# pupil_left                               0.00
# is_pupils_measured                       0.00
# is_urine_dipstick_clean_measured         0.00
# pain                                     0.00
# is_pain_measured                         0.00
# breathalyzer                             0.00
# is_breathalyzer_measured                 0.00
# hemocue                                  0.00
# is_hemocue_measured                      0.00
# had_ekg                                  0.00
# has_ultrasound                           0.00
# has_ct_scan                              0.00
# has_xray                                 0.00
# has_mri                                  0.00
# has_radio_interventional                 0.00
# has_nuclear_medicine                     0.00
# count_ultrasound                         0.00
# count_ct_scan                            0.00
# count_xray                               0.00
# count_mri                                0.00
# count_radio_interventional               0.00
# count_nuclear_medicine                   0.00
# imaging_exam_count                       0.00
# has_imaging_any                          0.00
# has_blood_gas                            0.00
# is_aXa_aIIa                              0.00
# has_lumbar_puncture                      0.00
# is_lactates                              0.00
# has_culture                              0.00
# is_leucocytes                            0.00
# is_formule_leuco                         0.00
# is_alat                                  0.00
# is_asat                                  0.00
# is_bnp                                   0.00
# is_bili_total                            0.00
# is_ck                                    0.00
# is_ckmb                                  0.00
# is_crp                                   0.00
# is_calcium_ionized                       0.00
# is_calcium                               0.00
# is_creatinine                            0.00
# is_ddimer                                0.00
# is_iron                                  0.00
# is_ferritin                              0.00
# is_fibrinogen                            0.00
# is_hemoglobine                           0.00
# is_lipase                                0.00
# is_alp                                   0.00
# is_platelets                             0.00
# is_potassium                             0.00
# is_pct                                   0.00
# is_sodium                                0.00
# is_aptt                                  0.00
# is_pt                                    0.00
# is_troponine                             0.00
# is_urea                                  0.00
# has_blood_test                           0.00
# bio_exam_count                           0.00
# is_labo                                  0.00
# 📋 --- CATEGORICAL & STATUS DISTRIBUTIONS ---
#                        Variable                                 Level      N  \
# 0                           sex                                     M  15603
# 1                           sex                                     F  14272
# 2                           sex                                     I      1
# 3                      hospital                                   PEL  29876
# 4                   mode_sortie                                   NaN  14601
# 5                   mode_sortie                          A - Domicile  12532
# 6                   mode_sortie                    B1 - Transfert MCO   1403
# 7                   mode_sortie                    B2 - Transfert SSR    487
# 8                   mode_sortie                    B4 - Transfert PSY    425
# 9                   mode_sortie                           C0 - Décédé    306
# 10                  mode_sortie                     D2 - Mutation SSR     39
# 11                  mode_sortie  C1 - Transfert provisoire (<48h) MCO     38
# 12                  mode_sortie                            A2 - Fugue     31
# 13                  mode_sortie            B3 - Transfert Long Séjour     14
# 14             decision_urgence                       Hospitalisation  15102
# 15             decision_urgence                          Consultation  14492
# 16             decision_urgence                                   NaN    281
# 17             decision_urgence                       Pas de décision      1
# 18            transport_grouped                              Personal  15089
# 19            transport_grouped                    Emergency services   6676
# 20            transport_grouped                               Unknown   4868
# 21            transport_grouped                             Ambulance   3099
# 22            transport_grouped                   Post medical advice    144
# 23                   triage_raw                  Urgent (médecin <1h)  11288
# 24                   triage_raw              Peu urgent (médecin <2h)   9062
# 25                   triage_raw          Très urgent (médecin <20min)   7472
# 26                   triage_raw              Non urgent (médecin <3h)   1959
# 27                   triage_raw           Réanimation (médecin <1min)     95
# 28                    bp_status                          normotension  11690
# 29                    bp_status                          not_measured   8368
# 30                    bp_status                          hypertension   7295
# 31                    bp_status                           hypotension   2523
# 32                    hr_status                           normocardia  18682
# 33                    hr_status                          not_measured   8402
# 34                    hr_status                           tachycardia   2588
# 35                    hr_status                           bradycardia    204
# 36                  temp_status                          normothermia  19778
# 37                  temp_status                          not_measured   8835
# 38                  temp_status                          hyperthermia    725
# 39                  temp_status                           hypothermia    538
# 40                   sat_status                                normal  20860
# 41                   sat_status                          not_measured   8456
# 42                   sat_status                               hypoxia    518
# 43                   sat_status                        severe hypoxia     42
# 44                    rr_status                          not_measured  24770
# 45                    rr_status                                normal   3487
# 46                    rr_status                             tachypnea   1360
# 47                    rr_status                             bradypnea    259
# 48               o2_flow_status                                   off  16724
# 49               o2_flow_status                          not_measured  12137
# 50               o2_flow_status                                    on   1015
# 51                   gcs_status                                normal  19092
# 52                   gcs_status                          not_measured  10538
# 53                   gcs_status                   moderate_impairment    167
# 54                   gcs_status                     severe_impairment     79
# 55       cap_blood_sugar_status                          not_measured  21927
# 56       cap_blood_sugar_status                         normoglycemia   6284
# 57       cap_blood_sugar_status                         hyperglycemia   1570
# 58       cap_blood_sugar_status                          hypoglycemia     95
# 59                pupils_status                          not_measured  25253
# 60                pupils_status                                normal   4508
# 61                pupils_status                                myosis     65
# 62                pupils_status                             mydriasis     50
# 63            anisocoria_status                          not_measured  25253
# 64            anisocoria_status                                    no   4076
# 65            anisocoria_status                                   yes    547
# 66         urine_dipstick_clean                              negative  28183
# 67         urine_dipstick_clean                        blood_positive    592
# 68         urine_dipstick_clean                          ecbu_ordered    329
# 69         urine_dipstick_clean                   leukocytes_positive    313
# 70         urine_dipstick_clean                              beta hcg    156
# 71         urine_dipstick_clean                     nitrites_positive    120
# 72         urine_dipstick_clean                      ketones_positive    111
# 73         urine_dipstick_clean                      protein_positive     72
# 74  urine_dipstick_clean_status                          not_measured  27669
# 75  urine_dipstick_clean_status                              positive   1693
# 76  urine_dipstick_clean_status                              negative    514
# 77                  pain_status                          not_measured  11848
# 78                  pain_status                               no_pain   9474
# 79                  pain_status                         moderate_pain   3486
# 80                  pain_status                             mild_pain   2673
# 81                  pain_status                           severe_pain   2395
# 82          breathalyzer_status                          not_measured  29155
# 83          breathalyzer_status                              positive    537
# 84          breathalyzer_status                              negative    184
# 85               hemocue_status                          not_measured  29168
# 86               hemocue_status                       moderate_anemia    394
# 87               hemocue_status                                normal    272
# 88               hemocue_status                         severe_anemia     42
# 89                  disposition                       retour domicile  16641
# 90                  disposition                               unknown   8759
# 91                  disposition                hospitalisation au chu   2323
# 92                  disposition      uhcd puis hospitalisation au chu    825
# 93                  disposition                         uhcd puis rad    711
# 94                  disposition                    transfert hors chu    460
# 95                  disposition          uhcd puis transfert hors chu    157
#
#     Percentage (%)
# 0             52.2
# 1             47.8
# 2              0.0
# 3            100.0
# 4             48.9
# 5             41.9
# 6              4.7
# 7              1.6
# 8              1.4
# 9              1.0
# 10             0.1
# 11             0.1
# 12             0.1
# 13             0.0
# 14            50.5
# 15            48.5
# 16             0.9
# 17             0.0
# 18            50.5
# 19            22.3
# 20            16.3
# 21            10.4
# 22             0.5
# 23            37.8
# 24            30.3
# 25            25.0
# 26             6.6
# 27             0.3
# 28            39.1
# 29            28.0
# 30            24.4
# 31             8.4
# 32            62.5
# 33            28.1
# 34             8.7
# 35             0.7
# 36            66.2
# 37            29.6
# 38             2.4
# 39             1.8
# 40            69.8
# 41            28.3
# 42             1.7
# 43             0.1
# 44            82.9
# 45            11.7
# 46             4.6
# 47             0.9
# 48            56.0
# 49            40.6
# 50             3.4
# 51            63.9
# 52            35.3
# 53             0.6
# 54             0.3
# 55            73.4
# 56            21.0
# 57             5.3
# 58             0.3
# 59            84.5
# 60            15.1
# 61             0.2
# 62             0.2
# 63            84.5
# 64            13.6
# 65             1.8
# 66            94.3
# 67             2.0
# 68             1.1
# 69             1.0
# 70             0.5
# 71             0.4
# 72             0.4
# 73             0.2
# 74            92.6
# 75             5.7
# 76             1.7
# 77            39.7
# 78            31.7
# 79            11.7
# 80             8.9
# 81             8.0
# 82            97.6
# 83             1.8
# 84             0.6
# 85            97.6
# 86             1.3
# 87             0.9
# 88             0.1
# 89            55.7
# 90            29.3
# 91             7.8
# 92             2.8
# 93             2.4
# 94             1.5
# 95             0.5

# %%
# ====================================================================================
# STEP 12: FINAL PHYSIOLOGICAL CLEANING & PEDIATRIC FILTERING
# ====================================================================================

# 1. PEDIATRIC FILTER (Adults >= 15 years old only)
if 'age' in df_imputed.columns:
    initial_total = len(df_imputed)
    df_imputed = df_imputed[df_imputed['age'] >= 15].reset_index(drop=True)
    print(f"🚫 PEDIATRIC FILTER: Removed {initial_total - len(df_imputed)} patients under 15.")

# 2. PHYSIOLOGICAL OUTLIER REMOVAL
# Thresholds adjusted for clinical reality (High Glucose capped at 33.3 mmol/L)
bounds = {
    'sbp': (50, 300), 'dbp': (30, 200), 'hr': (20, 300),
    'temp': (25, 43), 'sat': (40, 100), 'rr': (4, 60),
    'cap_blood_sugar_mmol_L': (1.1, 33.3), # LO to HI range
    'gcs': (3, 15), 'pain': (0, 10),
    'pupil_right': (1, 8), 'pupil_left': (1, 8),
    'o2_flow': (0, 15), 'hemocue': (5, 20),
    'breathalyzer': (0, 4.0)
}

# Tagging and removing outliers
present_cols = [c for c in bounds.keys() if c in df_imputed.columns]
for col, (min_val, max_val) in bounds.items():
    if col in df_imputed.columns:
        df_imputed.loc[(df_imputed[col] < min_val) | (df_imputed[col] > max_val), col] = np.nan

# Drop patients with any critical physiological outlier
initial_len = len(df_imputed)
df_imputed = df_imputed.dropna(subset=present_cols).reset_index(drop=True)
print(f"✅ PHYSIOLOGICAL CLEANING: {initial_len - len(df_imputed)} patients removed.")

# ====================================================================================
# STEP 13: TRIAGE DURATION & OUTCOME CLEANING
# ====================================================================================

# Cleaning 'diag' and 'disposition'
for col in ['diag', 'disposition']:
    if col in df_imputed.columns:
        df_imputed[col] = df_imputed[col].astype(str).str.lower().str.strip().replace(['nan', 'none', ''], 'unknown')

# Triage duration: removing outliers > 30 min or missing
df_imputed = df_imputed[
    (df_imputed['duration_triage_ioa_min'] <= 30) & (df_imputed['duration_triage_ioa_min'] >= 0)
].dropna(subset=['duration_triage_ioa_min']).reset_index(drop=True)



# ====================================================================================
# STEP 14: COMPLETE DASHBOARD EXECUTION
# ====================================================================================

def get_complete_dashboard(df):
    """
    Generates a full audit of numeric and categorical distributions.
    """
    exclude = ['nda', 'datetime_admission', 'date_hour_vitals', 'chief_complaint', 'sample_date']
    target_cols = [c for c in df.columns if c not in exclude]

    # Numeric Summary
    num_df = df[target_cols].select_dtypes(include=[np.number])
    num_summary = num_df.agg(['mean', 'std', 'min', 'max']).T
    num_summary['Missing %'] = (num_df.isna().sum() / len(df) * 100).round(2)

    # Categorical Summary (Threshold: <20 unique levels for readability)
    cat_df = df[target_cols].select_dtypes(exclude=[np.number])
    cat_cols = [c for c in cat_df.columns if df[c].nunique() < 20]

    rows = []
    for col in cat_cols:
        counts = df[col].value_counts(dropna=False)
        perc = df[col].value_counts(dropna=False, normalize=True) * 100
        for level in counts.index:
            rows.append({'Variable': col, 'Category': level,
                         'N': counts[level], '%': round(perc[level], 1)})

    return num_summary.round(2), pd.DataFrame(rows)

# Execution
numeric_stats, categorical_stats = get_complete_dashboard(df_imputed)

print("\n📊 --- NUMERIC SUMMARY ---")
display(numeric_stats)

print("\n📋 --- CATEGORICAL SUMMARY ---")
display(categorical_stats)
# Out:
# 🚫 PEDIATRIC FILTER: Removed 8 patients under 15.
# ✅ PHYSIOLOGICAL CLEANING: 28 patients removed.
#
# 📊 --- NUMERIC SUMMARY ---
#                                        mean     std      min      max  \
# age                                   46.65   22.83    15.00   104.00
# uam_service                         9780.00    0.00  9780.00  9780.00
# duration_triage_ioa_min                6.10    3.56     2.00    30.00
# triage                                 3.18    0.89     1.00     5.00
# sbp                                  127.15   19.69    52.00   253.00
# dbp                                   74.56   12.71    30.00   159.00
# mbp                                   94.20   15.59    37.30   190.30
# is_bp_measured                         0.72    0.45     0.00     1.00
# hr                                    79.16   14.47    20.00   220.00
# is_hr_measured                         0.72    0.45     0.00     1.00
# temp                                  36.88    0.49    32.20    40.50
# is_temp_measured                       0.70    0.46     0.00     1.00
# sat                                   97.87    1.74    49.00   100.00
# is_sat_measured                        0.72    0.45     0.00     1.00
# rr                                    18.07    2.47     4.00    60.00
# is_rr_measured                         0.17    0.38     0.00     1.00
# o2_flow                                0.14    1.03     0.00    15.00
# is_o2_measured                         0.59    0.49     0.00     1.00
# gcs                                   14.90    0.65     3.00    15.00
# is_gcs_measured                        0.65    0.48     0.00     1.00
# cap_blood_sugar_mmol_L                 5.85    1.62     1.66    33.30
# is_cap_blood_sugar_mmol_L_measured     0.27    0.44     0.00     1.00
# pupil_right                            2.93    0.32     1.00     6.00
# pupil_left                             2.93    0.32     1.00     6.00
# is_pupils_measured                     0.15    0.36     0.00     1.00
# is_urine_dipstick_clean_measured       0.07    0.26     0.00     1.00
# pain                                   1.43    2.58     0.00    10.00
# is_pain_measured                       0.60    0.49     0.00     1.00
# breathalyzer                           0.03    0.23     0.00     3.95
# is_breathalyzer_measured               0.02    0.15     0.00     1.00
# hemocue                               12.97    0.46     5.20    18.40
# is_hemocue_measured                    0.02    0.15     0.00     1.00
# had_ekg                                0.26    0.44     0.00     1.00
# has_ultrasound                         0.02    0.13     0.00     1.00
# has_ct_scan                            0.25    0.43     0.00     1.00
# has_xray                               0.23    0.42     0.00     1.00
# has_mri                                0.09    0.29     0.00     1.00
# has_radio_interventional               0.00    0.04     0.00     1.00
# has_nuclear_medicine                   0.00    0.01     0.00     1.00
# count_ultrasound                       0.02    0.13     0.00     2.00
# count_ct_scan                          0.26    0.45     0.00     3.00
# count_xray                             0.23    0.43     0.00     3.00
# count_mri                              0.09    0.29     0.00     2.00
# count_radio_interventional             0.00    0.04     0.00     1.00
# count_nuclear_medicine                 0.00    0.01     0.00     1.00
# imaging_exam_count                     0.60    0.65     0.00     4.00
# has_imaging_any                        0.51    0.50     0.00     1.00
# axa_arixtra                            0.46     NaN     0.46     0.46
# aiia_pradaxa                         201.97  210.04    30.00   897.00
# lactates_v                             1.47    0.96     0.56     7.24
# lymphocytes                            1.81    5.31     0.00   620.08
# monocytes                              0.69    0.39     0.00    15.46
# basophils                              0.04    0.12     0.00    14.52
# eosinophils                            0.11    0.15     0.00     4.45
# neutrophils                            7.00    4.36     0.02   153.20
# has_blood_gas                          0.07    0.26     0.00     1.00
# is_aXa_aIIa                            0.02    0.14     0.00     1.00
# has_lumbar_puncture                    0.01    0.09     0.00     1.00
# is_lactates                            0.07    0.26     0.00     1.00
# has_culture                            0.14    0.35     0.00     1.00
# is_leucocytes                          0.56    0.50     0.00     1.00
# is_formule_leuco                       0.52    0.50     0.00     1.00
# is_alat                                0.30    0.46     0.00     1.00
# is_asat                                0.30    0.46     0.00     1.00
# is_bnp                                 0.04    0.20     0.00     1.00
# is_bili_total                          0.30    0.46     0.00     1.00
# is_ck                                  0.12    0.33     0.00     1.00
# is_ckmb                                0.03    0.18     0.00     1.00
# is_crp                                 0.53    0.50     0.00     1.00
# is_calcium_ionized                     0.06    0.24     0.00     1.00
# is_calcium                             0.56    0.50     0.00     1.00
# is_creatinine                          0.56    0.50     0.00     1.00
# is_ddimer                              0.11    0.31     0.00     1.00
# is_iron                                0.00    0.05     0.00     1.00
# is_ferritin                            0.01    0.10     0.00     1.00
# is_fibrinogen                          0.08    0.26     0.00     1.00
# is_hemoglobine                         0.56    0.50     0.00     1.00
# is_lipase                              0.11    0.32     0.00     1.00
# is_alp                                 0.30    0.46     0.00     1.00
# is_platelets                           0.56    0.50     0.00     1.00
# is_potassium                           0.56    0.50     0.00     1.00
# is_pct                                 0.01    0.11     0.00     1.00
# is_sodium                              0.56    0.50     0.00     1.00
# is_aptt                                0.46    0.50     0.00     1.00
# is_pt                                  0.45    0.50     0.00     1.00
# is_troponine                           0.18    0.38     0.00     1.00
# is_urea                                0.56    0.50     0.00     1.00
# has_blood_test                         0.57    0.50     0.00     1.00
# bio_exam_count                         0.80    0.82     0.00     4.00
# is_labo                                0.58    0.49     0.00     1.00
#
#                                     Missing %
# age                                      0.00
# uam_service                              0.00
# duration_triage_ioa_min                  0.00
# triage                                   0.00
# sbp                                      0.00
# dbp                                      0.00
# mbp                                     28.03
# is_bp_measured                           0.00
# hr                                       0.00
# is_hr_measured                           0.00
# temp                                     0.00
# is_temp_measured                         0.00
# sat                                      0.00
# is_sat_measured                          0.00
# rr                                       0.00
# is_rr_measured                           0.00
# o2_flow                                  0.00
# is_o2_measured                           0.00
# gcs                                      0.00
# is_gcs_measured                          0.00
# cap_blood_sugar_mmol_L                   0.00
# is_cap_blood_sugar_mmol_L_measured       0.00
# pupil_right                              0.00
# pupil_left                               0.00
# is_pupils_measured                       0.00
# is_urine_dipstick_clean_measured         0.00
# pain                                     0.00
# is_pain_measured                         0.00
# breathalyzer                             0.00
# is_breathalyzer_measured                 0.00
# hemocue                                  0.00
# is_hemocue_measured                      0.00
# had_ekg                                  0.00
# has_ultrasound                           0.00
# has_ct_scan                              0.00
# has_xray                                 0.00
# has_mri                                  0.00
# has_radio_interventional                 0.00
# has_nuclear_medicine                     0.00
# count_ultrasound                         0.00
# count_ct_scan                            0.00
# count_xray                               0.00
# count_mri                                0.00
# count_radio_interventional               0.00
# count_nuclear_medicine                   0.00
# imaging_exam_count                       0.00
# has_imaging_any                          0.00
# axa_arixtra                            100.00
# aiia_pradaxa                            99.89
# lactates_v                              99.67
# lymphocytes                             48.30
# monocytes                               48.30
# basophils                               48.30
# eosinophils                             48.30
# neutrophils                             48.30
# has_blood_gas                            0.00
# is_aXa_aIIa                              0.00
# has_lumbar_puncture                      0.00
# is_lactates                              0.00
# has_culture                              0.00
# is_leucocytes                            0.00
# is_formule_leuco                         0.00
# is_alat                                  0.00
# is_asat                                  0.00
# is_bnp                                   0.00
# is_bili_total                            0.00
# is_ck                                    0.00
# is_ckmb                                  0.00
# is_crp                                   0.00
# is_calcium_ionized                       0.00
# is_calcium                               0.00
# is_creatinine                            0.00
# is_ddimer                                0.00
# is_iron                                  0.00
# is_ferritin                              0.00
# is_fibrinogen                            0.00
# is_hemoglobine                           0.00
# is_lipase                                0.00
# is_alp                                   0.00
# is_platelets                             0.00
# is_potassium                             0.00
# is_pct                                   0.00
# is_sodium                                0.00
# is_aptt                                  0.00
# is_pt                                    0.00
# is_troponine                             0.00
# is_urea                                  0.00
# has_blood_test                           0.00
# bio_exam_count                           0.00
# is_labo                                  0.00
# 📋 --- CATEGORICAL SUMMARY ---
#                         Variable  \
# 0                            sex
# 1                            sex
# 2                            sex
# 3                       hospital
# 4                    mode_sortie
# 5                    mode_sortie
# 6                    mode_sortie
# 7                    mode_sortie
# 8                    mode_sortie
# 9                    mode_sortie
# 10                   mode_sortie
# 11                   mode_sortie
# 12                   mode_sortie
# 13                   mode_sortie
# 14              decision_urgence
# 15              decision_urgence
# 16              decision_urgence
# 17              decision_urgence
# 18             transport_grouped
# 19             transport_grouped
# 20             transport_grouped
# 21             transport_grouped
# 22             transport_grouped
# 23                    triage_raw
# 24                    triage_raw
# 25                    triage_raw
# 26                    triage_raw
# 27                    triage_raw
# 28                     bp_status
# 29                     bp_status
# 30                     bp_status
# 31                     bp_status
# 32                     hr_status
# 33                     hr_status
# 34                     hr_status
# 35                     hr_status
# 36                   temp_status
# 37                   temp_status
# 38                   temp_status
# 39                   temp_status
# 40                    sat_status
# 41                    sat_status
# 42                    sat_status
# 43                    sat_status
# 44                     rr_status
# 45                     rr_status
# 46                     rr_status
# 47                     rr_status
# 48                o2_flow_status
# 49                o2_flow_status
# 50                o2_flow_status
# 51                    gcs_status
# 52                    gcs_status
# 53                    gcs_status
# 54                    gcs_status
# 55        cap_blood_sugar_status
# 56        cap_blood_sugar_status
# 57        cap_blood_sugar_status
# 58        cap_blood_sugar_status
# 59                 pupils_status
# 60                 pupils_status
# 61                 pupils_status
# 62                 pupils_status
# 63             anisocoria_status
# 64             anisocoria_status
# 65             anisocoria_status
# 66          urine_dipstick_clean
# 67          urine_dipstick_clean
# 68          urine_dipstick_clean
# 69          urine_dipstick_clean
# 70          urine_dipstick_clean
# 71          urine_dipstick_clean
# 72          urine_dipstick_clean
# 73          urine_dipstick_clean
# 74   urine_dipstick_clean_status
# 75   urine_dipstick_clean_status
# 76   urine_dipstick_clean_status
# 77                   pain_status
# 78                   pain_status
# 79                   pain_status
# 80                   pain_status
# 81                   pain_status
# 82           breathalyzer_status
# 83           breathalyzer_status
# 84           breathalyzer_status
# 85                hemocue_status
# 86                hemocue_status
# 87                hemocue_status
# 88                hemocue_status
# 89                   disposition
# 90                   disposition
# 91                   disposition
# 92                   disposition
# 93                   disposition
# 94                   disposition
# 95                   disposition
# 96                  ultrasound_2
# 97                  ultrasound_2
# 98                  ultrasound_2
# 99                  ultrasound_2
# 100                 ultrasound_2
# 101                 ultrasound_2
# 102                 ultrasound_2
# 103                 ultrasound_2
# 104                 ultrasound_2
# 105                    ct_scan_3
# 106                    ct_scan_3
# 107                    ct_scan_3
# 108                       xray_3
# 109                       xray_3
# 110                       xray_3
# 111                       xray_3
# 112                       xray_3
# 113                       xray_3
# 114                        mri_2
# 115                        mri_2
# 116                        mri_2
# 117                        mri_2
# 118                        mri_2
# 119                        mri_2
# 120                        mri_2
# 121                        mri_2
# 122                        mri_2
# 123                        mri_2
# 124                        mri_2
# 125       radio_interventional_1
# 126       radio_interventional_1
# 127       radio_interventional_1
# 128       radio_interventional_1
# 129       radio_interventional_1
# 130       radio_interventional_1
# 131       radio_interventional_1
# 132       radio_interventional_1
# 133       radio_interventional_1
# 134       radio_interventional_1
# 135       radio_interventional_1
# 136           nuclear_medicine_1
# 137           nuclear_medicine_1
# 138                      axa_hnf
# 139                      axa_hnf
# 140                      axa_hnf
# 141                      axa_hnf
# 142                      axa_hnf
# 143                      axa_hnf
# 144                      axa_hnf
# 145                      axa_hnf
# 146                      axa_hnf
# 147                      axa_hnf
# 148                      axa_hnf
# 149                      axa_hnf
# 150                      axa_hnf
# 151                      axa_hnf
# 152                      axa_hnf
# 153                      axa_hnf
# 154                      axa_hnf
# 155                      axa_hnf
# 156                      axa_hnf
# 157                      culture
# 158                      culture
# 159                   gds_origin
# 160                   gds_origin
# 161                   gds_origin
# 162                 lcr_aspect_1
# 163                 lcr_aspect_1
# 164                 lcr_aspect_1
# 165                 lcr_aspect_2
# 166                 lcr_aspect_2
# 167                 lcr_aspect_2
# 168                 lcr_aspect_2
# 169                 lcr_aspect_2
# 170                 lcr_aspect_2
# 171                 lcr_aspect_2
# 172                 lcr_aspect_2
# 173                 lcr_aspect_2
# 174                 lcr_aspect_2
# 175                 lcr_aspect_3
# 176                 lcr_aspect_3
# 177                 lcr_aspect_3
# 178                 lcr_aspect_3
# 179                 lcr_aspect_3
# 180                 lcr_aspect_3
# 181                 lcr_aspect_3
# 182                 lcr_aspect_3
# 183                 lcr_aspect_3
# 184                 lcr_aspect_3
# 185                 lcr_aspect_3
# 186                 lcr_aspect_3
# 187                 lcr_aspect_3
# 188                 lcr_aspect_3
# 189                 lcr_aspect_3
# 190                 lcr_aspect_3
# 191                 lcr_aspect_3
#
#                                               Category      N      %
# 0                                                    M  15580   52.2
# 1                                                    F  14259   47.8
# 2                                                    I      1    0.0
# 3                                                  PEL  29840  100.0
# 4                                                  NaN  14585   48.9
# 5                                         A - Domicile  12519   42.0
# 6                                   B1 - Transfert MCO   1401    4.7
# 7                                   B2 - Transfert SSR    485    1.6
# 8                                   B4 - Transfert PSY    425    1.4
# 9                                          C0 - Décédé    303    1.0
# 10                                   D2 - Mutation SSR     39    0.1
# 11                C1 - Transfert provisoire (<48h) MCO     38    0.1
# 12                                          A2 - Fugue     31    0.1
# 13                          B3 - Transfert Long Séjour     14    0.0
# 14                                     Hospitalisation  15083   50.5
# 15                                        Consultation  14476   48.5
# 16                                                 NaN    280    0.9
# 17                                     Pas de décision      1    0.0
# 18                                            Personal  15079   50.5
# 19                                  Emergency services   6661   22.3
# 20                                             Unknown   4860   16.3
# 21                                           Ambulance   3097   10.4
# 22                                 Post medical advice    143    0.5
# 23                                Urgent (médecin <1h)  11279   37.8
# 24                            Peu urgent (médecin <2h)   9051   30.3
# 25                        Très urgent (médecin <20min)   7459   25.0
# 26                            Non urgent (médecin <3h)   1957    6.6
# 27                         Réanimation (médecin <1min)     94    0.3
# 28                                        normotension  11677   39.1
# 29                                        not_measured   8363   28.0
# 30                                        hypertension   7288   24.4
# 31                                         hypotension   2512    8.4
# 32                                         normocardia  18658   62.5
# 33                                        not_measured   8397   28.1
# 34                                         tachycardia   2582    8.7
# 35                                         bradycardia    203    0.7
# 36                                        normothermia  19753   66.2
# 37                                        not_measured   8828   29.6
# 38                                        hyperthermia    724    2.4
# 39                                         hypothermia    535    1.8
# 40                                              normal  20832   69.8
# 41                                        not_measured   8451   28.3
# 42                                             hypoxia    516    1.7
# 43                                      severe hypoxia     41    0.1
# 44                                        not_measured  24744   82.9
# 45                                              normal   3480   11.7
# 46                                           tachypnea   1358    4.6
# 47                                           bradypnea    258    0.9
# 48                                                 off  16702   56.0
# 49                                        not_measured  12129   40.6
# 50                                                  on   1009    3.4
# 51                                              normal  19067   63.9
# 52                                        not_measured  10530   35.3
# 53                                 moderate_impairment    165    0.6
# 54                                   severe_impairment     78    0.3
# 55                                        not_measured  21909   73.4
# 56                                       normoglycemia   6269   21.0
# 57                                       hyperglycemia   1569    5.3
# 58                                        hypoglycemia     93    0.3
# 59                                        not_measured  25225   84.5
# 60                                              normal   4500   15.1
# 61                                              myosis     65    0.2
# 62                                           mydriasis     50    0.2
# 63                                        not_measured  25225   84.5
# 64                                                  no   4069   13.6
# 65                                                 yes    546    1.8
# 66                                            negative  28149   94.3
# 67                                      blood_positive    591    2.0
# 68                                        ecbu_ordered    329    1.1
# 69                                 leukocytes_positive    312    1.0
# 70                                            beta hcg    156    0.5
# 71                                   nitrites_positive    120    0.4
# 72                                    ketones_positive    111    0.4
# 73                                    protein_positive     72    0.2
# 74                                        not_measured  27635   92.6
# 75                                            positive   1691    5.7
# 76                                            negative    514    1.7
# 77                                        not_measured  11836   39.7
# 78                                             no_pain   9459   31.7
# 79                                       moderate_pain   3481   11.7
# 80                                           mild_pain   2671    9.0
# 81                                         severe_pain   2393    8.0
# 82                                        not_measured  29137   97.6
# 83                                            positive    519    1.7
# 84                                            negative    184    0.6
# 85                                        not_measured  29133   97.6
# 86                                     moderate_anemia    394    1.3
# 87                                              normal    271    0.9
# 88                                       severe_anemia     42    0.1
# 89                                     retour domicile  16619   55.7
# 90                                             unknown   8754   29.3
# 91                              hospitalisation au chu   2317    7.8
# 92                    uhcd puis hospitalisation au chu    825    2.8
# 93                                       uhcd puis rad    710    2.4
# 94                                  transfert hors chu    458    1.5
# 95                        uhcd puis transfert hors chu    157    0.5
# 96                                                 NaN  29829  100.0
# 97                                  scrotal ultrasound      3    0.0
# 98                    scrotal ultrasound with contrast      2    0.0
# 99                   upper limb soft tissue ultrasound      1    0.0
# 100                                  pelvic ultrasound      1    0.0
# 101                 liver and biliary tract ultrasound      1    0.0
# 102                               abdominal ultrasound      1    0.0
# 103              venous doppler ultrasound lower limb       1    0.0
# 104               venous doppler ultrasound upper limb      1    0.0
# 105                                                NaN  29837  100.0
# 106                                    ct head / brain      2    0.0
# 107                                           ct chest      1    0.0
# 108                                                NaN  29832  100.0
# 109                                 xray chest bedside      4    0.0
# 110                              xray dental panoramic      1    0.0
# 111                                   xray right ankle      1    0.0
# 112                                 xray left shoulder      1    0.0
# 113                                   xray right wrist      1    0.0
# 114                                                NaN  29795   99.8
# 115                                          mri brain     17    0.1
# 116                                    mri spinal cord     14    0.0
# 117                                 mri cervical spine      3    0.0
# 118                             mri brain facial bones      2    0.0
# 119                                mri stroke protocol      2    0.0
# 120                                   mri lumbar spine      2    0.0
# 121                         mri angiography neck brain      2    0.0
# 122                          mri brain and spinal cord      1    0.0
# 123      mri brain diffusion perfusion and angiography      1    0.0
# 124                                    mri whole spine      1    0.0
# 125                                                NaN  29800   99.9
# 126                     mechanical thrombectomy stroke     24    0.1
# 127                       gastrostomy tube replacement      8    0.0
# 128                                   hepatic drainage      1    0.0
# 129                                    lumbar puncture      1    0.0
# 130                           percutaneous nephrostomy      1    0.0
# 131                                    pelvic drainage      1    0.0
# 132                        genitourinary guided biopsy      1    0.0
# 133                         midline catheter insertion      1    0.0
# 134                                picc line insertion      1    0.0
# 135                            av fistula thrombectomy      1    0.0
# 136                                                NaN  29838  100.0
# 137   v/q lung scintigraphy pulmonary embolism krypton      2    0.0
# 138                                                NaN  29806   99.9
# 139                                                0.1     12    0.0
# 140                                                2.0      4    0.0
# 141                                               0.98      2    0.0
# 142                                               0.37      2    0.0
# 143                                               0.49      1    0.0
# 144                                                0.9      1    0.0
# 145                                               0.39      1    0.0
# 146                                               0.61      1    0.0
# 147                                               0.18      1    0.0
# 148                                               0.12      1    0.0
# 149                                                0.2      1    0.0
# 150                                               0.15      1    0.0
# 151                                               0.44      1    0.0
# 152                                               0.31      1    0.0
# 153                                               0.27      1    0.0
# 154                                               0.64      1    0.0
# 155                                               0.10      1    0.0
# 156                                               NREN      1    0.0
# 157                                                NaN  25545   85.6
# 158                                                YES   4295   14.4
# 159                                                NaN  27632   92.6
# 160                                           ARTERIEL   1758    5.9
# 161                                            VEINEUX    450    1.5
# 162                                                NaN  29837  100.0
# 163                                                EDR      2    0.0
# 164                                                edr      1    0.0
# 165                                                NaN  29620   99.3
# 166                                                EDR    166    0.6
# 167                                               ERHE     38    0.1
# 168                                               CIHE      7    0.0
# 169                                                CIT      3    0.0
# 170                                                edr      2    0.0
# 171                                               HEHE      1    0.0
# 172                                            {<NREA}      1    0.0
# 173                                       eau de roche      1    0.0
# 174                                              {<QI}      1    0.0
# 175                                                NaN  29617   99.3
# 176                                       Eau de Roche    170    0.6
# 177                                            Limpide     30    0.1
# 178                               Légèrement Hématique      4    0.0
# 179                                          Hématique      3    0.0
# 180                                 Légèrement trouble      3    0.0
# 181                                             Citrin      3    0.0
# 182                       Spiculée, cristaux brillants      1    0.0
# 183                                        Mamelonnée.      1    0.0
# 184                                               LIMP      1    0.0
# 185                                               LTRO      1    0.0
# 186                                       Hémorragique      1    0.0
# 187                                            Trouble      1    0.0
# 188                                                TRO      1    0.0
# 189                            Cristalline, blanc rosé      1    0.0
# 190  Surface mamelonnée avec un important voile gri...      1    0.0
# 191                                                EDR      1    0.0

# %%
#===============================
# table 1 on cleaned data
#================================

# NEW STATISTICAL SUMMARY
exclude_list = ['*date*', 'nda', 'uam_service' ]
numeric_cols = [c for c in df_imputed.select_dtypes(include=['number']).columns if c not in exclude_list]

print("=" * 60)
print("CLEANED QUANTITATIVE SUMMARY")
print("=" * 60)

clean_stats = df_imputed[numeric_cols].agg(['count', 'min', 'max', 'mean', 'median']).T
clean_stats['q25'] = df_imputed[numeric_cols].quantile(0.25).T
clean_stats['q75'] = df_imputed [numeric_cols].quantile(0.75).T
clean_stats['missing_%'] = ((df_imputed[numeric_cols].isna().sum() / len(df_imputed)) * 100).round(1)

# Order and display
ordered_cols = ['missing_%', 'count', 'min', 'q25', 'median', 'mean', 'q75', 'max']
print(clean_stats[ordered_cols].round(2))

print("\n" + "=" * 60)

print("CLEANED CATEGORICAL SUMMARY (Urine Dipstick)")
print("=" * 60)
if 'urine_dipstick_clean' in df_imputed.columns:
    counts = df_imputed['urine_dipstick_clean'].value_counts(dropna=False)
    percents = (df_imputed['urine_dipstick_clean'].value_counts(dropna=False, normalize=True) * 100).round(1)
    print(pd.DataFrame({'N': counts, '%': percents}))
# Out:
# ============================================================
# CLEANED QUANTITATIVE SUMMARY
# ============================================================
#                                     missing_%    count    min     q25  median  \
# age                                       0.0  29840.0  15.00   26.00   42.00
# duration_triage_ioa_min                   0.0  29840.0   2.00    4.00    5.00
# triage                                    0.0  29840.0   1.00    2.00    3.00
# sbp                                       0.0  29840.0  52.00  119.00  120.00
# dbp                                       0.0  29840.0  30.00   70.00   70.00
# mbp                                      28.0  21475.0  37.30   83.30   93.30
# is_bp_measured                            0.0  29840.0   0.00    0.00    1.00
# hr                                        0.0  29840.0  20.00   73.00   75.00
# is_hr_measured                            0.0  29840.0   0.00    0.00    1.00
# temp                                      0.0  29840.0  32.20   36.60   37.00
# is_temp_measured                          0.0  29840.0   0.00    0.00    1.00
# sat                                       0.0  29840.0  49.00   97.00   98.00
# is_sat_measured                           0.0  29840.0   0.00    0.00    1.00
# rr                                        0.0  29840.0   4.00   18.00   18.00
# is_rr_measured                            0.0  29840.0   0.00    0.00    0.00
# o2_flow                                   0.0  29840.0   0.00    0.00    0.00
# is_o2_measured                            0.0  29840.0   0.00    0.00    1.00
# gcs                                       0.0  29840.0   3.00   15.00   15.00
# is_gcs_measured                           0.0  29840.0   0.00    0.00    1.00
# cap_blood_sugar_mmol_L                    0.0  29840.0   1.66    5.50    5.50
# is_cap_blood_sugar_mmol_L_measured        0.0  29840.0   0.00    0.00    0.00
# pupil_right                               0.0  29840.0   1.00    3.00    3.00
# pupil_left                                0.0  29840.0   1.00    3.00    3.00
# is_pupils_measured                        0.0  29840.0   0.00    0.00    0.00
# is_urine_dipstick_clean_measured          0.0  29840.0   0.00    0.00    0.00
# pain                                      0.0  29840.0   0.00    0.00    0.00
# is_pain_measured                          0.0  29840.0   0.00    0.00    1.00
# breathalyzer                              0.0  29840.0   0.00    0.00    0.00
# is_breathalyzer_measured                  0.0  29840.0   0.00    0.00    0.00
# hemocue                                   0.0  29840.0   5.20   13.00   13.00
# is_hemocue_measured                       0.0  29840.0   0.00    0.00    0.00
# had_ekg                                   0.0  29840.0   0.00    0.00    0.00
# has_ultrasound                            0.0  29840.0   0.00    0.00    0.00
# has_ct_scan                               0.0  29840.0   0.00    0.00    0.00
# has_xray                                  0.0  29840.0   0.00    0.00    0.00
# has_mri                                   0.0  29840.0   0.00    0.00    0.00
# has_radio_interventional                  0.0  29840.0   0.00    0.00    0.00
# has_nuclear_medicine                      0.0  29840.0   0.00    0.00    0.00
# count_ultrasound                          0.0  29840.0   0.00    0.00    0.00
# count_ct_scan                             0.0  29840.0   0.00    0.00    0.00
# count_xray                                0.0  29840.0   0.00    0.00    0.00
# count_mri                                 0.0  29840.0   0.00    0.00    0.00
# count_radio_interventional                0.0  29840.0   0.00    0.00    0.00
# count_nuclear_medicine                    0.0  29840.0   0.00    0.00    0.00
# imaging_exam_count                        0.0  29840.0   0.00    0.00    1.00
# has_imaging_any                           0.0  29840.0   0.00    0.00    1.00
# axa_arixtra                             100.0      1.0   0.46    0.46    0.46
# aiia_pradaxa                             99.9     32.0  30.00   53.75  140.00
# lactates_v                               99.7     97.0   0.56    0.85    1.13
# lymphocytes                              48.3  15426.0   0.00    1.06    1.60
# monocytes                                48.3  15426.0   0.00    0.46    0.62
# basophils                                48.3  15426.0   0.00    0.02    0.04
# eosinophils                              48.3  15426.0   0.00    0.02    0.07
# neutrophils                              48.3  15426.0   0.02    4.21    5.97
# has_blood_gas                             0.0  29840.0   0.00    0.00    0.00
# is_aXa_aIIa                               0.0  29840.0   0.00    0.00    0.00
# has_lumbar_puncture                       0.0  29840.0   0.00    0.00    0.00
# is_lactates                               0.0  29840.0   0.00    0.00    0.00
# has_culture                               0.0  29840.0   0.00    0.00    0.00
# is_leucocytes                             0.0  29840.0   0.00    0.00    1.00
# is_formule_leuco                          0.0  29840.0   0.00    0.00    1.00
# is_alat                                   0.0  29840.0   0.00    0.00    0.00
# is_asat                                   0.0  29840.0   0.00    0.00    0.00
# is_bnp                                    0.0  29840.0   0.00    0.00    0.00
# is_bili_total                             0.0  29840.0   0.00    0.00    0.00
# is_ck                                     0.0  29840.0   0.00    0.00    0.00
# is_ckmb                                   0.0  29840.0   0.00    0.00    0.00
# is_crp                                    0.0  29840.0   0.00    0.00    1.00
# is_calcium_ionized                        0.0  29840.0   0.00    0.00    0.00
# is_calcium                                0.0  29840.0   0.00    0.00    1.00
# is_creatinine                             0.0  29840.0   0.00    0.00    1.00
# is_ddimer                                 0.0  29840.0   0.00    0.00    0.00
# is_iron                                   0.0  29840.0   0.00    0.00    0.00
# is_ferritin                               0.0  29840.0   0.00    0.00    0.00
# is_fibrinogen                             0.0  29840.0   0.00    0.00    0.00
# is_hemoglobine                            0.0  29840.0   0.00    0.00    1.00
# is_lipase                                 0.0  29840.0   0.00    0.00    0.00
# is_alp                                    0.0  29840.0   0.00    0.00    0.00
# is_platelets                              0.0  29840.0   0.00    0.00    1.00
# is_potassium                              0.0  29840.0   0.00    0.00    1.00
# is_pct                                    0.0  29840.0   0.00    0.00    0.00
# is_sodium                                 0.0  29840.0   0.00    0.00    1.00
# is_aptt                                   0.0  29840.0   0.00    0.00    0.00
# is_pt                                     0.0  29840.0   0.00    0.00    0.00
# is_troponine                              0.0  29840.0   0.00    0.00    0.00
# is_urea                                   0.0  29840.0   0.00    0.00    1.00
# has_blood_test                            0.0  29840.0   0.00    0.00    1.00
# bio_exam_count                            0.0  29840.0   0.00    0.00    1.00
# is_labo                                   0.0  29840.0   0.00    0.00    1.00
#
#                                       mean     q75     max
# age                                  46.65   65.00  104.00
# duration_triage_ioa_min               6.10    8.00   30.00
# triage                                3.18    4.00    5.00
# sbp                                 127.15  136.00  253.00
# dbp                                  74.56   81.00  159.00
# mbp                                  94.20  104.00  190.30
# is_bp_measured                        0.72    1.00    1.00
# hr                                   79.16   86.00  220.00
# is_hr_measured                        0.72    1.00    1.00
# temp                                 36.88   37.00   40.50
# is_temp_measured                      0.70    1.00    1.00
# sat                                  97.87   99.00  100.00
# is_sat_measured                       0.72    1.00    1.00
# rr                                   18.07   18.00   60.00
# is_rr_measured                        0.17    0.00    1.00
# o2_flow                               0.14    0.00   15.00
# is_o2_measured                        0.59    1.00    1.00
# gcs                                  14.90   15.00   15.00
# is_gcs_measured                       0.65    1.00    1.00
# cap_blood_sugar_mmol_L                5.85    5.50   33.30
# is_cap_blood_sugar_mmol_L_measured    0.27    1.00    1.00
# pupil_right                           2.93    3.00    6.00
# pupil_left                            2.93    3.00    6.00
# is_pupils_measured                    0.15    0.00    1.00
# is_urine_dipstick_clean_measured      0.07    0.00    1.00
# pain                                  1.43    2.00   10.00
# is_pain_measured                      0.60    1.00    1.00
# breathalyzer                          0.03    0.00    3.95
# is_breathalyzer_measured              0.02    0.00    1.00
# hemocue                              12.97   13.00   18.40
# is_hemocue_measured                   0.02    0.00    1.00
# had_ekg                               0.26    1.00    1.00
# has_ultrasound                        0.02    0.00    1.00
# has_ct_scan                           0.25    1.00    1.00
# has_xray                              0.23    0.00    1.00
# has_mri                               0.09    0.00    1.00
# has_radio_interventional              0.00    0.00    1.00
# has_nuclear_medicine                  0.00    0.00    1.00
# count_ultrasound                      0.02    0.00    2.00
# count_ct_scan                         0.26    1.00    3.00
# count_xray                            0.23    0.00    3.00
# count_mri                             0.09    0.00    2.00
# count_radio_interventional            0.00    0.00    1.00
# count_nuclear_medicine                0.00    0.00    1.00
# imaging_exam_count                    0.60    1.00    4.00
# has_imaging_any                       0.51    1.00    1.00
# axa_arixtra                           0.46    0.46    0.46
# aiia_pradaxa                        201.97  242.00  897.00
# lactates_v                            1.47    1.84    7.24
# lymphocytes                           1.81    2.24  620.08
# monocytes                             0.69    0.84   15.46
# basophils                             0.04    0.05   14.52
# eosinophils                           0.11    0.15    4.45
# neutrophils                           7.00    8.69  153.20
# has_blood_gas                         0.07    0.00    1.00
# is_aXa_aIIa                           0.02    0.00    1.00
# has_lumbar_puncture                   0.01    0.00    1.00
# is_lactates                           0.07    0.00    1.00
# has_culture                           0.14    0.00    1.00
# is_leucocytes                         0.56    1.00    1.00
# is_formule_leuco                      0.52    1.00    1.00
# is_alat                               0.30    1.00    1.00
# is_asat                               0.30    1.00    1.00
# is_bnp                                0.04    0.00    1.00
# is_bili_total                         0.30    1.00    1.00
# is_ck                                 0.12    0.00    1.00
# is_ckmb                               0.03    0.00    1.00
# is_crp                                0.53    1.00    1.00
# is_calcium_ionized                    0.06    0.00    1.00
# is_calcium                            0.56    1.00    1.00
# is_creatinine                         0.56    1.00    1.00
# is_ddimer                             0.11    0.00    1.00
# is_iron                               0.00    0.00    1.00
# is_ferritin                           0.01    0.00    1.00
# is_fibrinogen                         0.08    0.00    1.00
# is_hemoglobine                        0.56    1.00    1.00
# is_lipase                             0.11    0.00    1.00
# is_alp                                0.30    1.00    1.00
# is_platelets                          0.56    1.00    1.00
# is_potassium                          0.56    1.00    1.00
# is_pct                                0.01    0.00    1.00
# is_sodium                             0.56    1.00    1.00
# is_aptt                               0.46    1.00    1.00
# is_pt                                 0.45    1.00    1.00
# is_troponine                          0.18    0.00    1.00
# is_urea                               0.56    1.00    1.00
# has_blood_test                        0.57    1.00    1.00
# bio_exam_count                        0.80    1.00    4.00
# is_labo                               0.58    1.00    1.00
#
# ============================================================
# CLEANED CATEGORICAL SUMMARY (Urine Dipstick)
# ============================================================
#                           N     %
# urine_dipstick_clean
# negative              28149  94.3
# blood_positive          591   2.0
# ecbu_ordered            329   1.1
# leukocytes_positive     312   1.0
# beta hcg                156   0.5
# nitrites_positive       120   0.4
# ketones_positive        111   0.4
# protein_positive         72   0.2

# %%
# =========================================================
# SEX DISTRIBUTION & BINARY ENCODING
# =========================================================

# 1. Sex Distribution Audit (Counts and Percentages)
sex_stats = df_imputed['sex'].value_counts(dropna=False)
sex_pct = df_imputed['sex'].value_counts(normalize=True, dropna=False) * 100

print("📊 SEX DISTRIBUTION SUMMARY:")
for label, count in sex_stats.items():
    pct = sex_pct[label]
    print(f"  - Category {label}: {count} patients ({pct:.2f}%)")

# 2. Data Cleaning: Keep only 'M' and 'F'
# This removes potential NaNs or data entry errors to ensure binary integrity
initial_count = len(df_imputed)
df_imputed = df_imputed[df_imputed['sex'].isin(['M', 'F'])].copy()
removed_count = initial_count - len(df_imputed)

# 3. Binary Encoding (0 = Female, 1 = Male)
# Mapping ensures a clean transition for the GMM clustering algorithm
df_imputed['sex_bin'] = df_imputed['sex'].map({'F': 0, 'M': 1})

# 4. Final Verification and Index Reset
df_imputed = df_imputed.reset_index(drop=True)

print(f"\n✅ CLEANING COMPLETE:")
print(f"  - Removed {removed_count} records with invalid sex data.")
print(f"  - Final dataset size: {len(df_imputed)} patients.")
print("\n📊 NEW BINARY DISTRIBUTION (0=F, 1=M):")
print(df_imputed['sex_bin'].value_counts())

# Verification of the first 5 records
display(df_imputed[['sex', 'sex_bin']].head(5))
# Out:
# 📊 SEX DISTRIBUTION SUMMARY:
#   - Category M: 15580 patients (52.21%)
#   - Category F: 14259 patients (47.78%)
#   - Category I: 1 patients (0.00%)
#
# ✅ CLEANING COMPLETE:
#   - Removed 1 records with invalid sex data.
#   - Final dataset size: 29839 patients.
#
# 📊 NEW BINARY DISTRIBUTION (0=F, 1=M):
# sex_bin
# 1    15580
# 0    14259
# Name: count, dtype: int64
#   sex  sex_bin
# 0   M        1
# 1   F        0
# 2   M        1
# 3   F        0
# 4   F        0

# %%
# =========================================================
# STEP 16: CHIEF COMPLAINT (MOTIF) AUDIT & CLEANING
# =========================================================

# 1. Standardization & Investigation
# We check for technical NaNs and logical "empty" strings
n_unique_complaints = df_imputed['chief_complaint'].nunique()
n_missing_complaints = df_imputed['chief_complaint'].isna().sum()
pct_missing_complaints = (n_missing_complaints / len(df_imputed)) * 100

print(f"📊 CHIEF COMPLAINT ('chief_complaint') ANALYSIS:")
print(f"- Unique categories found: {n_unique_complaints}")
print(f"- Missing values (NaN)   : {n_missing_complaints} ({pct_missing_complaints:.2f}%)")

# 2. Imputation: Set NaNs and empty strings to 'unknown'
# We perform a robust cleaning: strip whitespace, lowercase, and fill NaNs
df_imputed['chief_complaint'] = (
    df_imputed['chief_complaint']
    .astype(str)
    .str.lower()
    .str.strip()
    .replace(['nan', 'none', '', 'nat', 'null'], 'unknown')
)

# 3. Final Verification
final_unknown_count = (df_imputed['chief_complaint'] == 'unknown').sum()
print(f"✅ CLEANING COMPLETE: All missing motifs are now tagged as 'unknown'.")
print(f"✅ Total 'unknown' records: {final_unknown_count} ({(final_unknown_count/len(df_imputed)*100):.2f}%)")

# Preview top 10 complaints for quality check
print("\n📋 TOP 10 MOST FREQUENT MOTIFS:")
print(df_imputed['chief_complaint'].value_counts().head(10))
# Out:
# 📊 CHIEF COMPLAINT ('chief_complaint') ANALYSIS:
# - Unique categories found: 179
# - Missing values (NaN)   : 0 (0.00%)
# ✅ CLEANING COMPLETE: All missing motifs are now tagged as 'unknown'.
# ✅ Total 'unknown' records: 0 (0.00%)
#
# 📋 TOP 10 MOST FREQUENT MOTIFS:
# chief_complaint
# douleurs abdominales récentes                                            2949
# traumatisme du membre inférieur hors cuisse fracture ouverte luxation    2078
# traumatisme du membre supérieur sans fracture ouverte sans luxation      1215
# traumatisme crânien sans défaillance vitale                              1031
# douleur non traumatique d'un membre                                       869
# troubles de la sensibilité cutanée ou paresthésies                        795
# plaie traumatique isolée                                                  791
# lombalgies                                                                707
# douleur thoracique récente                                                679
# troubles du langage récents                                               667
# Name: count, dtype: int64

# %% [markdown]
# 179 motifs rien que sur 2022, qu'est ce que je fais de ca  ???

# %% [markdown]
# # DISPOSITION MANAGING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ================================================================
# CONFIGURATION
# ================================================================
AUDIT_COLS     = ['disposition', 'mode_sortie', 'decision_urgence']
HOSPIT_KEYWORDS = ['admitted', 'transfer']

DISPOSITION_MAPPING = {
    'retour domicile':                  'Discharged',
    'unknown':                          'Unknown',
    'hospitalisation au chu':           'Admitted',
    'uhcd puis hospitalisation au chu': 'Admitted (via Obs)',
    'uhcd puis rad':                    'Discharged (via Obs)',
    'transfert hors chu':               'Transfer',
    'uhcd puis transfert hors chu':     'Transfer (via Obs)',
}

# ================================================================
# STEP 1 — COHERENCE AUDIT
# ================================================================
print("=" * 60)
print("STEP 1 — COHERENCE AUDIT")
print("=" * 60)

cols_present = [c for c in AUDIT_COLS if c in df_imputed.columns]
df_audit = df_imputed[cols_present].copy()

# Standardize strings
for col in cols_present:
    df_audit[col] = (df_audit[col].astype(str)
                     .replace(['nan', 'None', 'NAT', 'NaN', 'null'], 'missing')
                     .str.lower().str.strip())

print(f"Audit columns found: {cols_present}")

# Cross-tabulations for each pair of available columns
pairs = [
    ('disposition',    'mode_sortie',      'Medical Disposition vs Administrative Exit'),
    ('disposition',    'decision_urgence', 'Medical Disposition vs ED Decision'),
    ('mode_sortie',    'decision_urgence', 'Administrative Exit vs ED Decision'),
]
for col_a, col_b, title in pairs:
    if col_a in df_audit.columns and col_b in df_audit.columns:
        print(f"\n📊 {title}")
        table = pd.crosstab(df_audit[col_a], df_audit[col_b], margins=True)
        display(table)
        table.to_csv(f"audit_{col_a}_vs_{col_b}.csv", encoding='utf-8')

# Conflict detection: hospitalized in medical notes but discharged in admin records
if {'disposition', 'mode_sortie'}.issubset(df_audit.columns):
    conflicts = df_audit[
        df_audit['disposition'].str.contains('hospit|admitted', na=False) &
        df_audit['mode_sortie'].str.contains('domicile|rad|home', na=False)
    ]
    if len(conflicts) > 0:
        print(f"\n⚠️  {len(conflicts)} conflicting cases (Admitted vs Discharged)")
        nda_col = [c for c in df_imputed.columns if 'nda' in c.lower()]
        display_cols = (nda_col or []) + ['disposition', 'mode_sortie']
        conflicts_full = df_imputed.loc[conflicts.index, display_cols]
        display(conflicts_full.head())
        conflicts_full.to_csv("audit_conflicts_hospit_vs_home.csv", index=False)


# ================================================================
# STEP 2 — DISPOSITION MAPPING (FR → EN)
# ================================================================
print("\n" + "=" * 60)
print("STEP 2 — DISPOSITION MAPPING (FR → EN)")
print("=" * 60)

df_imputed['disposition'] = (
    df_imputed['disposition']
    .astype(str)
    .str.lower()
    .str.strip()
)

df_imputed['disposition'] = df_imputed['disposition'].map(DISPOSITION_MAPPING)

# Quick distribution check
counts = df_imputed['disposition'].value_counts(dropna=False)
pcts   = df_imputed['disposition'].value_counts(dropna=False, normalize=True) * 100
print(pd.concat([counts, pcts.round(1)], axis=1)
      .rename(columns={0: 'N', 1: '%'}))

n_nan = df_imputed['disposition'].isna().sum()
if n_nan > 0:
    print(f"\n⚠️  {n_nan} unmapped values → NaN (check DISPOSITION_MAPPING)")
else:
    print("\n✅ All values mapped successfully")

print(df_imputed['disposition'].value_counts(dropna=False))
print(df_imputed['disposition'].dtype)
# ================================================================
# STEP 3 — BINARY OUTCOME ENCODING
# ================================================================
print("\n" + "=" * 60)
print("STEP 3 — BINARY OUTCOME ENCODING")
print("=" * 60)

# hospitalization: 1 = Admitted / Transferred / ICU / Obs
df_imputed['hospitalization'] = (
    df_imputed['disposition']
    .astype(str)
    .str.lower().str.strip()
    .apply(lambda v: int(any(k in str(v) for k in HOSPIT_KEYWORDS)))
)

# observation_unit: passed through UHCD/Obs
df_imputed['observation_unit'] = (
    df_imputed['disposition']
    .astype(str)
    .str.contains('Obs', case=False, na=False).astype(int)
)

# inter_facility_transfer
df_imputed['inter_facility_transfer'] = (
    df_imputed['disposition']
    .astype(str)
    .str.contains('Transfer', case=False, na=False).astype(int)
)

# Summary
for col in ['hospitalization', 'observation_unit', 'inter_facility_transfer']:
    counts = df_imputed[col].value_counts()
    pcts   = df_imputed[col].value_counts(normalize=True) * 100
    print(f"\n{col}:")
    for val in [1, 0]:
        if val in counts:
            print(f"  {val} : {counts[val]:>6} ({pcts[val]:.1f}%)")

# Mapping audit
print("\n🔍 Mapping audit (hospitalization):")
display(pd.crosstab(df_imputed['disposition'], df_imputed['hospitalization']))

# ================================================================
# STEP 4 — DISPOSITION DISTRIBUTION PLOT
# ================================================================
plt.figure(figsize=(10, 5))
sns.countplot(
    data=df_imputed, y='disposition',
    order=df_imputed['disposition'].value_counts().index,
    palette='viridis'
)
plt.title('Patient Disposition Distribution')
plt.xlabel('Number of patients')
plt.ylabel('Disposition')
plt.tight_layout()
plt.savefig("disposition_distribution.png", dpi=150)
plt.show()
# Out:
# ============================================================
# STEP 1 — COHERENCE AUDIT
# ============================================================
# Audit columns found: ['disposition', 'mode_sortie', 'decision_urgence']
#
# 📊 Medical Disposition vs Administrative Exit
# mode_sortie                       a - domicile  a2 - fugue  \
# disposition
# hospitalisation au chu                    1425           7
# retour domicile                           6479           8
# transfert hors chu                          70           0
# uhcd puis hospitalisation au chu           434           2
# uhcd puis rad                              672           1
# uhcd puis transfert hors chu                19           0
# unknown                                   3420          13
# All                                      12519          31
#
# mode_sortie                       b1 - transfert mco  b2 - transfert ssr  \
# disposition
# hospitalisation au chu                           519                 154
# retour domicile                                   39                  30
# transfert hors chu                               120                  20
# uhcd puis hospitalisation au chu                 248                  75
# uhcd puis rad                                      9                   5
# uhcd puis transfert hors chu                      66                  13
# unknown                                          400                 188
# All                                             1401                 485
#
# mode_sortie                       b3 - transfert long séjour  \
# disposition
# hospitalisation au chu                                     5
# retour domicile                                            1
# transfert hors chu                                         0
# uhcd puis hospitalisation au chu                           3
# uhcd puis rad                                              0
# uhcd puis transfert hors chu                               1
# unknown                                                    4
# All                                                       14
#
# mode_sortie                       b4 - transfert psy  c0 - décédé  \
# disposition
# hospitalisation au chu                            40           81
# retour domicile                                   52            6
# transfert hors chu                               156            1
# uhcd puis hospitalisation au chu                  16           38
# uhcd puis rad                                      5            2
# uhcd puis transfert hors chu                      55            0
# unknown                                          101          175
# All                                              425          303
#
# mode_sortie                       c1 - transfert provisoire (<48h) mco  \
# disposition
# hospitalisation au chu                                              10
# retour domicile                                                      3
# transfert hors chu                                                  10
# uhcd puis hospitalisation au chu                                     0
# uhcd puis rad                                                        0
# uhcd puis transfert hors chu                                         0
# unknown                                                             15
# All                                                                 38
#
# mode_sortie                       d2 - mutation ssr  missing    All
# disposition
# hospitalisation au chu                           13       63   2317
# retour domicile                                   0    10001  16619
# transfert hors chu                                1       80    458
# uhcd puis hospitalisation au chu                  7        2    825
# uhcd puis rad                                     0       16    710
# uhcd puis transfert hors chu                      0        3    157
# unknown                                          18     4419   8753
# All                                              39    14584  29839
# 📊 Medical Disposition vs ED Decision
# decision_urgence                  consultation  hospitalisation  missing  \
# disposition
# hospitalisation au chu                      64             2228       25
# retour domicile                           9922             6553      143
# transfert hors chu                          80              373        5
# uhcd puis hospitalisation au chu             2              821        2
# uhcd puis rad                               16              685        9
# uhcd puis transfert hors chu                 3              151        3
# unknown                                   4388             4272       93
# All                                      14475            15083      280
#
# decision_urgence                  pas de décision    All
# disposition
# hospitalisation au chu                          0   2317
# retour domicile                                 1  16619
# transfert hors chu                              0    458
# uhcd puis hospitalisation au chu                0    825
# uhcd puis rad                                   0    710
# uhcd puis transfert hors chu                    0    157
# unknown                                         0   8753
# All                                             1  29839
# 📊 Administrative Exit vs ED Decision
# decision_urgence                      consultation  hospitalisation  missing  \
# mode_sortie
# a - domicile                                     1            12370      148
# a2 - fugue                                       0               31        0
# b1 - transfert mco                               0             1390       11
# b2 - transfert ssr                               0              483        2
# b3 - transfert long séjour                       0               14        0
# b4 - transfert psy                               0              417        8
# c0 - décédé                                      0              302        1
# c1 - transfert provisoire (<48h) mco             0               37        1
# d2 - mutation ssr                                0               39        0
# missing                                      14474                0      109
# All                                          14475            15083      280
#
# decision_urgence                      pas de décision    All
# mode_sortie
# a - domicile                                        0  12519
# a2 - fugue                                          0     31
# b1 - transfert mco                                  0   1401
# b2 - transfert ssr                                  0    485
# b3 - transfert long séjour                          0     14
# b4 - transfert psy                                  0    425
# c0 - décédé                                         0    303
# c1 - transfert provisoire (<48h) mco                0     38
# d2 - mutation ssr                                   0     39
# missing                                             1  14584
# All                                                 1  29839
# ⚠️  1859 conflicting cases (Admitted vs Discharged)
#             nda                       disposition   mode_sortie
# 7   22030011642            hospitalisation au chu  A - Domicile
# 29  22030011735            hospitalisation au chu  A - Domicile
# 34  22030011754  uhcd puis hospitalisation au chu  A - Domicile
# 63  22030012006  uhcd puis hospitalisation au chu  A - Domicile
# 67  22030012037            hospitalisation au chu  A - Domicile
# ============================================================
# STEP 2 — DISPOSITION MAPPING (FR → EN)
# ============================================================
#                       count  proportion
# disposition
# Discharged            16619        55.7
# Unknown                8753        29.3
# Admitted               2317         7.8
# Admitted (via Obs)      825         2.8
# Discharged (via Obs)    710         2.4
# Transfer                458         1.5
# Transfer (via Obs)      157         0.5
#
# ✅ All values mapped successfully
# disposition
# Discharged              16619
# Unknown                  8753
# Admitted                 2317
# Admitted (via Obs)        825
# Discharged (via Obs)      710
# Transfer                  458
# Transfer (via Obs)        157
# Name: count, dtype: int64
# object
#
# ============================================================
# STEP 3 — BINARY OUTCOME ENCODING
# ============================================================
#
# hospitalization:
#   1 :   3757 (12.6%)
#   0 :  26082 (87.4%)
#
# observation_unit:
#   1 :   1692 (5.7%)
#   0 :  28147 (94.3%)
#
# inter_facility_transfer:
#   1 :    615 (2.1%)
#   0 :  29224 (97.9%)
#
# 🔍 Mapping audit (hospitalization):
# hospitalization           0     1
# disposition
# Admitted                  0  2317
# Admitted (via Obs)        0   825
# Discharged            16619     0
# Discharged (via Obs)    710     0
# Transfer                  0   458
# Transfer (via Obs)        0   157
# Unknown                8753     0
# /tmp/ipykernel_520081/1744190776.py:144: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# # =========================================================
# # HARMONISATION DU FORMAT DES VARIABLES POUR LE CLUSTERING
# # =========================================================

# %%
# VISUALISATION DES FORMATS ACTUELS
# On crée un petit tableau de diagnostic
diagnostic = pd.DataFrame({
    'Type': df_imputed.dtypes,
    'Exemple': df_imputed.iloc[0], # On prend la première ligne pour voir
    'Nb_Valeurs_Uniques': df_imputed.nunique(),
    'Taux_NaN (%)': (df_imputed.isna().sum() / len(df_imputed) * 100).round(2)
})

print("### DIAGNOSTIC DES FORMATS ###")
print(diagnostic)
# Out:
# ### DIAGNOSTIC DES FORMATS ###
#                                        Type                       Exemple  \
# nda                                   int64                   22030011617
# sex                                  object                             M
# age                                   int64                            39
# uam_service                           int64                          9780
# hospital                             object                           PEL
# datetime_admission                   object           2022-01-01 00:08:00
# date_sortie                          object           2022-01-02 09:33:00
# mode_sortie                          object                  A - Domicile
# decision_urgence                     object               Hospitalisation
# transport_grouped                    object                       Unknown
# date_tri_ioa_begin                   object           2022-01-01 00:19:00
# date_tri_ioa_end                     object           2022-01-01 00:29:00
# duration_triage_ioa_min             float64                          10.0
# chief_complaint                      object  victime d'agression physique
# triage                                int64                             3
# triage_raw                           object          Urgent (médecin <1h)
# date_hour_vitals                     object                           NaN
# sbp                                 float64                         120.0
# dbp                                 float64                          70.0
# mbp                                 float64                           NaN
# bp_status                            object                  not_measured
# is_bp_measured                        int64                             0
# hr                                  float64                          75.0
# hr_status                            object                  not_measured
# is_hr_measured                        int64                             0
# temp                                float64                          37.0
# temp_status                          object                  not_measured
# is_temp_measured                      int64                             0
# sat                                 float64                          98.0
# sat_status                           object                  not_measured
# is_sat_measured                       int64                             0
# rr                                  float64                          18.0
# rr_status                            object                  not_measured
# is_rr_measured                        int64                             0
# o2_flow                             float64                           0.0
# o2_flow_status                       object                  not_measured
# is_o2_measured                        int64                             0
# gcs                                 float64                          15.0
# gcs_status                           object                  not_measured
# is_gcs_measured                       int64                             0
# cap_blood_sugar_mmol_L              float64                           5.5
# cap_blood_sugar_status               object                  not_measured
# is_cap_blood_sugar_mmol_L_measured    int64                             0
# pupil_right                         float64                           3.0
# pupil_left                          float64                           3.0
# pupils_status                        object                  not_measured
# anisocoria_status                    object                  not_measured
# is_pupils_measured                    int64                             0
# urine_dipstick_clean                 object                      negative
# is_urine_dipstick_clean_measured      int64                             0
# urine_dipstick_clean_status          object                  not_measured
# pain                                float64                           0.0
# pain_status                          object                  not_measured
# is_pain_measured                      int64                             0
# breathalyzer                        float64                           0.0
# breathalyzer_status                  object                  not_measured
# is_breathalyzer_measured              int64                             0
# hemocue                             float64                          13.0
# is_hemocue_measured                   int64                             0
# hemocue_status                       object                  not_measured
# diag                                 object                       unknown
# had_ekg                               int64                             0
# disposition                          object                    Discharged
# has_ultrasound                        int64                             0
# has_ct_scan                           int64                             1
# has_xray                              int64                             1
# has_mri                               int64                             0
# has_radio_interventional              int64                             0
# has_nuclear_medicine                  int64                             0
# count_ultrasound                      int64                             0
# count_ct_scan                         int64                             1
# count_xray                            int64                             1
# count_mri                             int64                             0
# count_radio_interventional            int64                             0
# count_nuclear_medicine                int64                             0
# ultrasound_1                         object                           NaN
# ultrasound_2                         object                           NaN
# ct_scan_1                            object               ct head / brain
# ct_scan_2                            object                           NaN
# ct_scan_3                            object                           NaN
# xray_1                               object         xray emergency survey
# xray_2                               object                           NaN
# xray_3                               object                           NaN
# mri_1                                object                           NaN
# mri_2                                object                           NaN
# radio_interventional_1               object                           NaN
# nuclear_medicine_1                   object                           NaN
# imaging_exam_count                    int64                             2
# has_imaging_any                       int64                             1
# sample_date                          object           2022-01-01 01:00:00
# alat                                 object                           NaN
# asat                                 object                           NaN
# axa_hnf                              object                           NaN
# axa_arixtra                         float64                           NaN
# axa_eliquis                          object                           NaN
# axa_hbpm                             object                           NaN
# axa_xarelto                          object                           NaN
# aiia_pradaxa                        float64                           NaN
# bnp                                  object                           NaN
# gds_hco3                             object                           NaN
# bili_total                           object                           NaN
# ck                                   object                           NaN
# ckmb                                 object                           NaN
# crp                                  object                           0.4
# calcium_ionized                      object                           NaN
# calcium                              object                          2.38
# creatinine                           object                            57
# ddimer                               object                           NaN
# iron                                 object                           NaN
# ferritin                             object                           NaN
# fibrinogen                           object                           2.7
# hemoglobine                          object                          13.7
# lactates_a                           object                           NaN
# lactates_v                          float64                           NaN
# leucocytes                           object                         11.39
# lipase                               object                           NaN
# lymphocytes                         float64                          1.67
# monocytes                           float64                          0.88
# alp                                  object                           NaN
# basophils                           float64                          0.07
# eosinophils                         float64                          0.17
# neutrophils                         float64                           8.6
# platelets                            object                           347
# potassium                            object                          NREN
# pct                                  object                           NaN
# gds_so2                              object                           NaN
# sodium                               object                           139
# aptt                                 object                          32.2
# pt                                   object                           147
# troponine                            object                           NaN
# urea                                 object                           1.3
# culture                              object                           NaN
# gds_origin                           object                           NaN
# lcr_aspect_1                         object                           NaN
# lcr_aspect_2                         object                           NaN
# lcr_aspect_3                         object                           NaN
# gds_pco2                             object                           NaN
# gds_ph                               object                           NaN
# gds_po2                              object                           NaN
# has_blood_gas                         int64                             0
# is_aXa_aIIa                           int64                             0
# has_lumbar_puncture                   int64                             0
# is_lactates                           int64                             0
# has_culture                           int64                             0
# is_leucocytes                         int64                             1
# is_formule_leuco                      int64                             1
# is_alat                               int64                             0
# is_asat                               int64                             0
# is_bnp                                int64                             0
# is_bili_total                         int64                             0
# is_ck                                 int64                             0
# is_ckmb                               int64                             0
# is_crp                                int64                             1
# is_calcium_ionized                    int64                             0
# is_calcium                            int64                             1
# is_creatinine                         int64                             1
# is_ddimer                             int64                             0
# is_iron                               int64                             0
# is_ferritin                           int64                             0
# is_fibrinogen                         int64                             1
# is_hemoglobine                        int64                             1
# is_lipase                             int64                             0
# is_alp                                int64                             0
# is_platelets                          int64                             1
# is_potassium                          int64                             1
# is_pct                                int64                             0
# is_sodium                             int64                             1
# is_aptt                               int64                             1
# is_pt                                 int64                             1
# is_troponine                          int64                             0
# is_urea                               int64                             1
# has_blood_test                        int64                             1
# bio_exam_count                        int64                             1
# is_labo                               int64                             1
# sex_bin                               int64                             1
# hospitalization                       int64                             0
# observation_unit                      int64                             0
# inter_facility_transfer               int64                             0
#
#                                     Nb_Valeurs_Uniques  Taux_NaN (%)
# nda                                              29839          0.00
# sex                                                  2          0.00
# age                                                 90          0.00
# uam_service                                          1          0.00
# hospital                                             1          0.00
# datetime_admission                               29424          0.00
# date_sortie                                      27144          0.00
# mode_sortie                                          9         48.88
# decision_urgence                                     3          0.94
# transport_grouped                                    5          0.00
# date_tri_ioa_begin                               29427          0.01
# date_tri_ioa_end                                 29457          0.00
# duration_triage_ioa_min                             29          0.00
# chief_complaint                                    179          0.00
# triage                                               5          0.00
# triage_raw                                           5          0.00
# date_hour_vitals                                  1061         96.33
# sbp                                                180          0.00
# dbp                                                119          0.00
# mbp                                                336         28.03
# bp_status                                            4          0.00
# is_bp_measured                                       2          0.00
# hr                                                 136          0.00
# hr_status                                            4          0.00
# is_hr_measured                                       2          0.00
# temp                                                75          0.00
# temp_status                                          4          0.00
# is_temp_measured                                     2          0.00
# sat                                                 30          0.00
# sat_status                                           4          0.00
# is_sat_measured                                      2          0.00
# rr                                                  49          0.00
# rr_status                                            4          0.00
# is_rr_measured                                       2          0.00
# o2_flow                                             25          0.00
# o2_flow_status                                       3          0.00
# is_o2_measured                                       2          0.00
# gcs                                                 13          0.00
# gcs_status                                           4          0.00
# is_gcs_measured                                      2          0.00
# cap_blood_sugar_mmol_L                             345          0.00
# cap_blood_sugar_status                               4          0.00
# is_cap_blood_sugar_mmol_L_measured                   2          0.00
# pupil_right                                          6          0.00
# pupil_left                                           6          0.00
# pupils_status                                        4          0.00
# anisocoria_status                                    3          0.00
# is_pupils_measured                                   2          0.00
# urine_dipstick_clean                                 8          0.00
# is_urine_dipstick_clean_measured                     2          0.00
# urine_dipstick_clean_status                          3          0.00
# pain                                                11          0.00
# pain_status                                          5          0.00
# is_pain_measured                                     2          0.00
# breathalyzer                                       254          0.00
# breathalyzer_status                                  3          0.00
# is_breathalyzer_measured                             2          0.00
# hemocue                                            123          0.00
# is_hemocue_measured                                  2          0.00
# hemocue_status                                       4          0.00
# diag                                               490          0.00
# had_ekg                                              2          0.00
# disposition                                          7          0.00
# has_ultrasound                                       2          0.00
# has_ct_scan                                          2          0.00
# has_xray                                             2          0.00
# has_mri                                              2          0.00
# has_radio_interventional                             2          0.00
# has_nuclear_medicine                                 2          0.00
# count_ultrasound                                     3          0.00
# count_ct_scan                                        4          0.00
# count_xray                                           4          0.00
# count_mri                                            3          0.00
# count_radio_interventional                           2          0.00
# count_nuclear_medicine                               2          0.00
# ultrasound_1                                        33         98.33
# ultrasound_2                                         8         99.96
# ct_scan_1                                           46         74.94
# ct_scan_2                                           25         99.52
# ct_scan_3                                            2         99.99
# xray_1                                              80         77.43
# xray_2                                              29         99.48
# xray_3                                               5         99.97
# mri_1                                               26         90.93
# mri_2                                               10         99.85
# radio_interventional_1                              10         99.87
# nuclear_medicine_1                                   1         99.99
# imaging_exam_count                                   5          0.00
# has_imaging_any                                      2          0.00
# sample_date                                      15558         41.97
# alat                                               435         69.82
# asat                                               322         69.81
# axa_hnf                                             18         99.89
# axa_arixtra                                          1        100.00
# axa_eliquis                                        260         98.82
# axa_hbpm                                            25         99.88
# axa_xarelto                                         98         99.54
# aiia_pradaxa                                        27         99.89
# bnp                                                586         95.86
# gds_hco3                                           506         92.63
# bili_total                                         245         70.36
# ck                                                 990         87.98
# ckmb                                               153         96.78
# crp                                               2561         47.33
# calcium_ionized                                    128         93.91
# calcium                                            260         44.37
# creatinine                                         507         43.65
# ddimer                                            1543         89.10
# iron                                                73         99.70
# ferritin                                           276         99.07
# fibrinogen                                         154         92.43
# hemoglobine                                        285         43.51
# lactates_a                                         148         93.06
# lactates_v                                          77         99.67
# leucocytes                                        3523         43.73
# lipase                                             335         88.60
# lymphocytes                                        595         48.30
# monocytes                                          277         48.30
# alp                                                390         70.35
# basophils                                           48         48.30
# eosinophils                                        135         48.30
# neutrophils                                       1873         48.30
# platelets                                          645         43.75
# potassium                                          432         43.61
# pct                                                145         98.81
# gds_so2                                            459         92.62
# sodium                                             105         43.61
# aptt                                               406         54.28
# pt                                                 141         54.58
# troponine                                          345         82.38
# urea                                               394         43.66
# culture                                              1         85.61
# gds_origin                                           2         92.60
# lcr_aspect_1                                         2         99.99
# lcr_aspect_2                                         9         99.26
# lcr_aspect_3                                        16         99.25
# gds_pco2                                           192         92.63
# gds_ph                                             145         92.61
# gds_po2                                            411         92.62
# has_blood_gas                                        2          0.00
# is_aXa_aIIa                                          2          0.00
# has_lumbar_puncture                                  2          0.00
# is_lactates                                          2          0.00
# has_culture                                          2          0.00
# is_leucocytes                                        2          0.00
# is_formule_leuco                                     2          0.00
# is_alat                                              2          0.00
# is_asat                                              2          0.00
# is_bnp                                               2          0.00
# is_bili_total                                        2          0.00
# is_ck                                                2          0.00
# is_ckmb                                              2          0.00
# is_crp                                               2          0.00
# is_calcium_ionized                                   2          0.00
# is_calcium                                           2          0.00
# is_creatinine                                        2          0.00
# is_ddimer                                            2          0.00
# is_iron                                              2          0.00
# is_ferritin                                          2          0.00
# is_fibrinogen                                        2          0.00
# is_hemoglobine                                       2          0.00
# is_lipase                                            2          0.00
# is_alp                                               2          0.00
# is_platelets                                         2          0.00
# is_potassium                                         2          0.00
# is_pct                                               2          0.00
# is_sodium                                            2          0.00
# is_aptt                                              2          0.00
# is_pt                                                2          0.00
# is_troponine                                         2          0.00
# is_urea                                              2          0.00
# has_blood_test                                       2          0.00
# bio_exam_count                                       5          0.00
# is_labo                                              2          0.00
# sex_bin                                              2          0.00
# hospitalization                                      2          0.00
# observation_unit                                     2          0.00
# inter_facility_transfer                              2          0.00

# %%
# =========================================================
# DATA TYPE OPTIMIZATION (CATEGORICAL & NUMERIC)
# =========================================================

# --- 1. FEATURE ENGINEERING: AGE QUARTILES ---
if 'age' in df_imputed.columns:
    df_imputed['age_group'] = pd.qcut(df_imputed['age'], q=4,
                                     labels=['Q1_Young', 'Q2_Lower_Mid', 'Q3_Upper_Mid', 'Q4_Senior'])

# --- 2. AUTOMATED CATEGORICAL CONVERSION ---
# We identify columns based on your naming convention + explicit clinical targets
patterns = ['is_', 'has_', '_status', 'imagerie']
explicit_cats = ['transport_grouped', 'urine_dipstick_clean', 'disposition', 'sex', 'age_group', 'hospitalization']

# Dynamic selection
cols_to_categorize = [
    col for col in df_imputed.columns
    if any(p in col for p in patterns) or col in explicit_cats
]

for col in cols_to_categorize:
    df_imputed[col] = df_imputed[col].astype('category')

print(f"✅ Categorical conversion complete: {len(cols_to_categorize)} columns processed.")
print(f"   (Includes: {', '.join(cols_to_categorize[:5])}...)")

# --- 3. NUMERIC CONVERSION (NULLABLE INTEGERS) ---
# Using 'Int64' allows integers to coexist with NaNs
cols_to_int = [
    'sbp', 'dbp', 'hr', 'rr', 'gcs', 'pain',
    'age', 'triage_level'
]

for col in cols_to_int:
    if col in df_imputed.columns:
        df_imputed[col] = pd.to_numeric(df_imputed[col], errors='coerce').astype('Int64')

print("✅ Integer conversion complete for physiological vitals and age.")

# --- 4. TEXT & DATETIME STANDARDIZATION ---
# Text
for col in ['diag', 'chief_complaint']:
    if col in df_imputed.columns:
        df_imputed[col] = df_imputed[col].astype(str).str.lower().str.strip()

# Datetimes
cols_dates = ['datetime_admission', 'date_hour_vitals', 'sample_date', 'date_tri_ioa_begin', 'date_tri_ioa_end']
for col in cols_dates:
    if col in df_imputed.columns:
        df_imputed[col] = pd.to_datetime(df_imputed[col], errors='coerce')

print("✅ Text and Datetime formats standardized.")
# Out:
# ✅ Categorical conversion complete: 74 columns processed.
#    (Includes: sex, transport_grouped, bp_status, is_bp_measured, hr_status...)
# ✅ Integer conversion complete for physiological vitals and age.
# ✅ Text and Datetime formats standardized.

# %%
# =========================================================
# DATA DICTIONARY & FORMAT AUDIT
# =========================================================

# 1. Create the Audit Table
data_audit = pd.DataFrame({
    'Column Name': df_imputed.columns,
    'Data Type': [df_imputed[col].dtype for col in df_imputed.columns],
    'Category?': [pd.api.types.is_categorical_dtype(df_imputed[col]) for col in df_imputed.columns],
    'Missing Values': [df_imputed[col].isna().sum() for col in df_imputed.columns],
    'Sample Value': [df_imputed[col].dropna().iloc[0] if not df_imputed[col].dropna().empty else "Empty" for col in df_imputed.columns]
})

# 2. Add a 'Group' tag for easier reading
def tag_group(col):
    if any(p in col for p in ['is_', 'has_', '_status', 'imagerie', 'bin']): return 'Categorical/Flag'
    if any(p in col for p in ['date', 'time']): return 'Temporal'
    if col in ['age', 'sbp', 'dbp', 'hr', 'rr', 'sat', 'temp', 'gcs', 'pain']: return 'Vital Signs'
    return 'Other'

data_audit['Analysis Group'] = data_audit['Column Name'].apply(tag_group)

# 3. Display the sorted audit
print("📋 FINAL DATA FORMAT AUDIT:")
print("-" * 60)
display(data_audit.sort_values(by='Analysis Group'))

# 4. Quick Summary of Types
print("\n📊 DATA TYPE SUMMARY:")
print(df_imputed.dtypes.value_counts())
# Out:
# 📋 FINAL DATA FORMAT AUDIT:
# ------------------------------------------------------------
# /tmp/ipykernel_520081/1175692346.py:9: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   'Category?': [pd.api.types.is_categorical_dtype(df_imputed[col]) for col in df_imputed.columns],
#                             Column Name       Data Type  Category?  \
# 52                          pain_status        category       True
# 53                     is_pain_measured        category       True
# 111                         hemoglobine          object      False
# 147                             is_asat        category       True
# 50          urine_dipstick_clean_status        category       True
# 49     is_urine_dipstick_clean_measured        category       True
# 148                              is_bnp        category       True
# 146                             is_alat        category       True
# 47                   is_pupils_measured        category       True
# 45                        pupils_status        category       True
# 149                       is_bili_total        category       True
# 150                               is_ck        category       True
# 41               cap_blood_sugar_status        category       True
# 151                             is_ckmb        category       True
# 39                      is_gcs_measured        category       True
# 46                    anisocoria_status        category       True
# 55                  breathalyzer_status        category       True
# 56             is_breathalyzer_measured        category       True
# 145                    is_formule_leuco        category       True
# 88                      has_imaging_any        category       True
# 139                       has_blood_gas        category       True
# 140                         is_aXa_aIIa        category       True
# 141                 has_lumbar_puncture        category       True
# 68                 has_nuclear_medicine        category       True
# 67             has_radio_interventional        category       True
# 66                              has_mri        category       True
# 65                             has_xray        category       True
# 64                          has_ct_scan        category       True
# 63                       has_ultrasound        category       True
# 142                         is_lactates        category       True
# 143                         has_culture        category       True
# 144                       is_leucocytes        category       True
# 59                       hemocue_status        category       True
# 58                  is_hemocue_measured        category       True
# 38                           gcs_status        category       True
# 152                              is_crp        category       True
# 42   is_cap_blood_sugar_mmol_L_measured        category       True
# 35                       o2_flow_status        category       True
# 160                      is_hemoglobine        category       True
# 161                           is_lipase        category       True
# 162                              is_alp        category       True
# 163                        is_platelets        category       True
# 164                        is_potassium        category       True
# 36                       is_o2_measured        category       True
# 159                       is_fibrinogen        category       True
# 166                           is_sodium        category       True
# 168                               is_pt        category       True
# 169                        is_troponine        category       True
# 170                             is_urea        category       True
# 171                      has_blood_test        category       True
# 173                             is_labo        category       True
# 174                             sex_bin           int64      False
# 167                             is_aptt        category       True
# 158                         is_ferritin        category       True
# 165                              is_pct        category       True
# 21                       is_bp_measured        category       True
# 20                            bp_status        category       True
# 33                       is_rr_measured        category       True
# 32                            rr_status        category       True
# 154                          is_calcium        category       True
# 30                      is_sat_measured        category       True
# 29                           sat_status        category       True
# 153                  is_calcium_ionized        category       True
# 27                     is_temp_measured        category       True
# 26                          temp_status        category       True
# 156                           is_ddimer        category       True
# 24                       is_hr_measured        category       True
# 23                            hr_status        category       True
# 157                             is_iron        category       True
# 155                       is_creatinine        category       True
# 108                                iron          object      False
# 122                           platelets          object      False
# 121                         neutrophils         float64      False
# 120                         eosinophils         float64      False
# 119                           basophils         float64      False
# 118                                 alp          object      False
# 117                           monocytes         float64      False
# 114                          leucocytes          object      False
# 115                              lipase          object      False
# 113                          lactates_v         float64      False
# 112                          lactates_a          object      False
# 109                            ferritin          object      False
# 110                          fibrinogen          object      False
# 123                           potassium          object      False
# 116                         lymphocytes         float64      False
# 124                                 pct          object      False
# 0                                   nda           int64      False
# 126                              sodium          object      False
# 176                    observation_unit           int64      False
# 175                     hospitalization        category       True
# 172                      bio_exam_count           int64      False
# 107                              ddimer          object      False
# 138                             gds_po2          object      False
# 137                              gds_ph          object      False
# 136                            gds_pco2          object      False
# 125                             gds_so2          object      False
# 135                        lcr_aspect_3          object      False
# 133                        lcr_aspect_1          object      False
# 132                          gds_origin          object      False
# 131                             culture          object      False
# 130                                urea          object      False
# 129                           troponine          object      False
# 128                                  pt          object      False
# 127                                aptt          object      False
# 134                        lcr_aspect_2          object      False
# 106                          creatinine          object      False
# 178                           age_group        category       True
# 104                     calcium_ionized          object      False
# 72                            count_mri           int64      False
# 71                           count_xray           int64      False
# 70                        count_ct_scan           int64      False
# 69                     count_ultrasound           int64      False
# 105                             calcium          object      False
# 61                              had_ekg           int64      False
# 60                                 diag          object      False
# 57                              hemocue         float64      False
# 54                         breathalyzer         float64      False
# 48                 urine_dipstick_clean        category       True
# 44                           pupil_left         float64      False
# 43                          pupil_right         float64      False
# 40               cap_blood_sugar_mmol_L         float64      False
# 34                              o2_flow         float64      False
# 19                                  mbp         float64      False
# 15                           triage_raw          object      False
# 14                               triage           int64      False
# 13                      chief_complaint          object      False
# 12              duration_triage_ioa_min         float64      False
# 9                     transport_grouped        category       True
# 8                      decision_urgence          object      False
# 7                           mode_sortie          object      False
# 4                              hospital          object      False
# 3                           uam_service           int64      False
# 1                                   sex        category       True
# 73           count_radio_interventional           int64      False
# 74               count_nuclear_medicine           int64      False
# 62                          disposition        category       True
# 76                         ultrasound_2          object      False
# 96                          axa_xarelto          object      False
# 95                             axa_hbpm          object      False
# 94                          axa_eliquis          object      False
# 98                                  bnp          object      False
# 99                             gds_hco3          object      False
# 100                          bili_total          object      False
# 93                          axa_arixtra         float64      False
# 75                         ultrasound_1          object      False
# 101                                  ck          object      False
# 92                              axa_hnf          object      False
# 102                                ckmb          object      False
# 97                         aiia_pradaxa         float64      False
# 90                                 alat          object      False
# 91                                 asat          object      False
# 87                   imaging_exam_count           int64      False
# 103                                 crp          object      False
# 86                   nuclear_medicine_1          object      False
# 85               radio_interventional_1          object      False
# 84                                mri_2          object      False
# 83                                mri_1          object      False
# 82                               xray_3          object      False
# 81                               xray_2          object      False
# 80                               xray_1          object      False
# 79                            ct_scan_3          object      False
# 78                            ct_scan_2          object      False
# 77                            ct_scan_1          object      False
# 177             inter_facility_transfer           int64      False
# 5                    datetime_admission  datetime64[ns]      False
# 6                           date_sortie          object      False
# 10                   date_tri_ioa_begin  datetime64[ns]      False
# 89                          sample_date  datetime64[ns]      False
# 16                     date_hour_vitals  datetime64[ns]      False
# 11                     date_tri_ioa_end  datetime64[ns]      False
# 17                                  sbp           Int64      False
# 18                                  dbp           Int64      False
# 25                                 temp         float64      False
# 28                                  sat         float64      False
# 31                                   rr           Int64      False
# 37                                  gcs           Int64      False
# 2                                   age           Int64      False
# 51                                 pain           Int64      False
# 22                                   hr           Int64      False
#
#      Missing Values                                      Sample Value  \
# 52                0                                      not_measured
# 53                0                                                 0
# 111           12984                                              13.7
# 147               0                                                 0
# 50                0                                      not_measured
# 49                0                                                 0
# 148               0                                                 0
# 146               0                                                 0
# 47                0                                                 0
# 45                0                                      not_measured
# 149               0                                                 0
# 150               0                                                 0
# 41                0                                      not_measured
# 151               0                                                 0
# 39                0                                                 0
# 46                0                                      not_measured
# 55                0                                      not_measured
# 56                0                                                 0
# 145               0                                                 1
# 88                0                                                 1
# 139               0                                                 0
# 140               0                                                 0
# 141               0                                                 0
# 68                0                                                 0
# 67                0                                                 0
# 66                0                                                 0
# 65                0                                                 1
# 64                0                                                 1
# 63                0                                                 0
# 142               0                                                 0
# 143               0                                                 0
# 144               0                                                 1
# 59                0                                      not_measured
# 58                0                                                 0
# 38                0                                      not_measured
# 152               0                                                 1
# 42                0                                                 0
# 35                0                                      not_measured
# 160               0                                                 1
# 161               0                                                 0
# 162               0                                                 0
# 163               0                                                 1
# 164               0                                                 1
# 36                0                                                 0
# 159               0                                                 1
# 166               0                                                 1
# 168               0                                                 1
# 169               0                                                 0
# 170               0                                                 1
# 171               0                                                 1
# 173               0                                                 1
# 174               0                                                 1
# 167               0                                                 1
# 158               0                                                 0
# 165               0                                                 0
# 21                0                                                 0
# 20                0                                      not_measured
# 33                0                                                 0
# 32                0                                      not_measured
# 154               0                                                 1
# 30                0                                                 0
# 29                0                                      not_measured
# 153               0                                                 0
# 27                0                                                 0
# 26                0                                      not_measured
# 156               0                                                 0
# 24                0                                                 0
# 23                0                                      not_measured
# 157               0                                                 0
# 155               0                                                 1
# 108           29749                                             {<QI}
# 122           13054                                               347
# 121           14413                                               8.6
# 120           14413                                              0.17
# 119           14413                                              0.07
# 118           20992                                               272
# 117           14413                                              0.88
# 114           13050                                             11.39
# 115           26438                                                29
# 113           29742                                              0.68
# 112           27769                                               1.3
# 109           29561                                           2692.52
# 110           27580                                               2.7
# 123           13014                                              NREN
# 116           14413                                              1.67
# 124           29484                                              0.11
# 0                 0                                       22030011617
# 126           13014                                               139
# 176               0                                                 0
# 175               0                                                 0
# 172               0                                                 1
# 107           26586                                               683
# 138           27638                                               9.9
# 137           27633                                               7.5
# 136           27639                                               4.9
# 125           27638                                              97.1
# 135           29616                                      Eau de Roche
# 133           29836                                               EDR
# 132           27631                                          ARTERIEL
# 131           25544                                               YES
# 130           13028                                               1.3
# 129           24582                                                 5
# 128           16286                                               147
# 127           16197                                              32.2
# 134           29619                                               EDR
# 106           13026                                                57
# 178               0                                      Q2_Lower_Mid
# 104           28022                                              1.22
# 72                0                                                 0
# 71                0                                                 1
# 70                0                                                 1
# 69                0                                                 0
# 105           13239                                              2.38
# 61                0                                                 0
# 60                0                                           unknown
# 57                0                                              13.0
# 54                0                                               0.0
# 48                0                                          negative
# 44                0                                               3.0
# 43                0                                               3.0
# 40                0                                               5.5
# 34                0                                               0.0
# 19             8365                                              83.3
# 15                0                              Urgent (médecin <1h)
# 14                0                                                 3
# 13                0                      victime d'agression physique
# 12                0                                              10.0
# 9                 0                                           Unknown
# 8               280                                   Hospitalisation
# 7             14584                                      A - Domicile
# 4                 0                                               PEL
# 3                 0                                              9780
# 1                 0                                                 M
# 73                0                                                 0
# 74                0                                                 0
# 62                0                                        Discharged
# 76            29828                                scrotal ultrasound
# 96            29701                                             382.0
# 95            29802                                               0.1
# 94            29486                                             147.0
# 98            28605                                             597.0
# 99            27639                                              28.9
# 100           20996                                                 5
# 93            29838                                              0.46
# 75            29341                        scrotal doppler ultrasound
# 101           26252                                             118.0
# 92            29805                                               0.1
# 102           28877                                              NREN
# 97            29807                                             443.0
# 90            20833                                                38
# 91            20832                                                37
# 87                0                                                 2
# 103           14123                                               0.4
# 86            29837  v/q lung scintigraphy pulmonary embolism krypton
# 85            29799                    mechanical thrombectomy stroke
# 84            29794                                         mri brain
# 83            27134     mri brain diffusion perfusion and angiography
# 82            29831                                xray chest bedside
# 81            29685                                        xray skull
# 80            23103                             xray emergency survey
# 79            29836                                   ct head / brain
# 78            29697                             ct brain facial bones
# 77            22361                                   ct head / brain
# 177               0                                                 0
# 5                 0                               2022-01-01 00:08:00
# 6                 1                               2022-01-02 09:33:00
# 10                2                               2022-01-01 00:19:00
# 89            12522                               2022-01-01 01:00:00
# 16            28744                               2022-01-01 13:00:00
# 11                0                               2022-01-01 00:29:00
# 17                0                                               120
# 18                0                                                70
# 25                0                                              37.0
# 28                0                                              98.0
# 31                0                                                18
# 37                0                                                15
# 2                 0                                                39
# 51                0                                                 0
# 22                0                                                75
#
#        Analysis Group
# 52   Categorical/Flag
# 53   Categorical/Flag
# 111  Categorical/Flag
# 147  Categorical/Flag
# 50   Categorical/Flag
# 49   Categorical/Flag
# 148  Categorical/Flag
# 146  Categorical/Flag
# 47   Categorical/Flag
# 45   Categorical/Flag
# 149  Categorical/Flag
# 150  Categorical/Flag
# 41   Categorical/Flag
# 151  Categorical/Flag
# 39   Categorical/Flag
# 46   Categorical/Flag
# 55   Categorical/Flag
# 56   Categorical/Flag
# 145  Categorical/Flag
# 88   Categorical/Flag
# 139  Categorical/Flag
# 140  Categorical/Flag
# 141  Categorical/Flag
# 68   Categorical/Flag
# 67   Categorical/Flag
# 66   Categorical/Flag
# 65   Categorical/Flag
# 64   Categorical/Flag
# 63   Categorical/Flag
# 142  Categorical/Flag
# 143  Categorical/Flag
# 144  Categorical/Flag
# 59   Categorical/Flag
# 58   Categorical/Flag
# 38   Categorical/Flag
# 152  Categorical/Flag
# 42   Categorical/Flag
# 35   Categorical/Flag
# 160  Categorical/Flag
# 161  Categorical/Flag
# 162  Categorical/Flag
# 163  Categorical/Flag
# 164  Categorical/Flag
# 36   Categorical/Flag
# 159  Categorical/Flag
# 166  Categorical/Flag
# 168  Categorical/Flag
# 169  Categorical/Flag
# 170  Categorical/Flag
# 171  Categorical/Flag
# 173  Categorical/Flag
# 174  Categorical/Flag
# 167  Categorical/Flag
# 158  Categorical/Flag
# 165  Categorical/Flag
# 21   Categorical/Flag
# 20   Categorical/Flag
# 33   Categorical/Flag
# 32   Categorical/Flag
# 154  Categorical/Flag
# 30   Categorical/Flag
# 29   Categorical/Flag
# 153  Categorical/Flag
# 27   Categorical/Flag
# 26   Categorical/Flag
# 156  Categorical/Flag
# 24   Categorical/Flag
# 23   Categorical/Flag
# 157  Categorical/Flag
# 155  Categorical/Flag
# 108             Other
# 122             Other
# 121             Other
# 120             Other
# 119             Other
# 118             Other
# 117             Other
# 114             Other
# 115             Other
# 113             Other
# 112             Other
# 109             Other
# 110             Other
# 123             Other
# 116             Other
# 124             Other
# 0               Other
# 126             Other
# 176             Other
# 175             Other
# 172             Other
# 107             Other
# 138             Other
# 137             Other
# 136             Other
# 125             Other
# 135             Other
# 133             Other
# 132             Other
# 131             Other
# 130             Other
# 129             Other
# 128             Other
# 127             Other
# 134             Other
# 106             Other
# 178             Other
# 104             Other
# 72              Other
# 71              Other
# 70              Other
# 69              Other
# 105             Other
# 61              Other
# 60              Other
# 57              Other
# 54              Other
# 48              Other
# 44              Other
# 43              Other
# 40              Other
# 34              Other
# 19              Other
# 15              Other
# 14              Other
# 13              Other
# 12              Other
# 9               Other
# 8               Other
# 7               Other
# 4               Other
# 3               Other
# 1               Other
# 73              Other
# 74              Other
# 62              Other
# 76              Other
# 96              Other
# 95              Other
# 94              Other
# 98              Other
# 99              Other
# 100             Other
# 93              Other
# 75              Other
# 101             Other
# 92              Other
# 102             Other
# 97              Other
# 90              Other
# 91              Other
# 87              Other
# 103             Other
# 86              Other
# 85              Other
# 84              Other
# 83              Other
# 82              Other
# 81              Other
# 80              Other
# 79              Other
# 78              Other
# 77              Other
# 177             Other
# 5            Temporal
# 6            Temporal
# 10           Temporal
# 89           Temporal
# 16           Temporal
# 11           Temporal
# 17        Vital Signs
# 18        Vital Signs
# 25        Vital Signs
# 28        Vital Signs
# 31        Vital Signs
# 37        Vital Signs
# 2         Vital Signs
# 51        Vital Signs
# 22        Vital Signs
# 📊 DATA TYPE SUMMARY:
# object            60
# category          55
# float64           18
# int64             15
# Int64              7
# datetime64[ns]     5
# category           2
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# category           1
# Name: count, dtype: int64

# %%
# sauvegarde du df_imputed nettoyé et prêt pour l'analyse
df_imputed.to_csv("df_final_binaire_imputed.csv", index=False)
print("\n✅ Le gros fichier 'df_final_binaire_imputed.csv' est prêt")
# Out:
# ✅ Le gros fichier 'df_final_binaire_imputed.csv' est prêt
